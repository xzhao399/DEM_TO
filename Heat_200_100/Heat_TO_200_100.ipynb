# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install necessary packages
# !pip install tf_fourier_features
# !pip install geomdl
# Out:
# Collecting tf_fourier_features
#   Downloading tf_fourier_features-0.0.2.1-py2.py3-none-any.whl (6.2 kB)
# Requirement already satisfied: tensorflow>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from tf_fourier_features) (2.15.0)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from tf_fourier_features) (1.25.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.2.0->tf_fourier_features) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.2.2)
# Installing collected packages: tf_fourier_features
# Successfully installed tf_fourier_features-0.0.2.1
# Collecting geomdl
#   Downloading geomdl-5.3.1-py2.py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: geomdl
# Successfully installed geomdl-5.3.1

# %%
# # compile the mma for the current python version
# !cd {folder_path}MMA && sh compile.sh

# %%
# import standard packages
from __future__ import division
from numpy import *
import numpy as np
from scipy.sparse import coo_matrix
from matplotlib import colors
import matplotlib.pyplot as plt
import tensorflow as tf
import sys
import time
import os
import gc
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
# path of current folder
folder_path = '/content/drive/MyDrive/DEM_TO/Heat_200_100/'
# add the path to python's search list
sys.path.append(folder_path)
sys.path.append(folder_path+'UtilityFunctions/')

# %%
# import custimized modules
import utils as ut
import surrogate_model_primal as sm_pr
from mma import mmasub

# %%
# use gpu for tensorflow
if tf.config.list_physical_devices('GPU'):
  physical_devices = tf.config.list_physical_devices('GPU')
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
  print('Using GPU')
else:
  print('Using CPU')
# Out:
# Using GPU

# %%
ut.makepath(folder_path+'TOdesign')
ut.makepath(folder_path+'surrogate_result')
ut.makepath(folder_path+'model_pr')
# Out:
# '/content/drive/MyDrive/DEM_TO/Heat_200_100/surrogate_result/'

# %%
class TO2D_heat():
    def __init__(self,Lx=100,Ly=50,nelx=100,nely=50,volfrac=0.5,rmin=3,maxiter=1000,filter=0,x_init=0.5):
        self.Lx = Lx
        self.Ly = Ly
        self.nelx = nelx
        self.nely = nely
        self.volfrac = volfrac
        self.rmin = rmin
        self.maxiter = maxiter
        self.ft = filter
        self.x_init = x_init* np.ones(self.nely*self.nelx,dtype=float)
        print("2D TO for heat sink")
        print("Number of nodes: " + str(self.nelx) + " x " + str(self.nely))
        print("Volume fraction: " + str(self.volfrac) + ", rmin: " + str(self.rmin))
        print("Filter method: " + ["Density based","Density based + Heaviside filter"][self.ft])

    def optimize(self):
        x = self.x_init.copy()
        nn = len(x)
        mm = 1
        [geps,xval,move,xmin,xmax,fmax,mma_a,mma_c] = self.mmaInit(mm, nn, self.volfrac)
        xlow = xmin
        xupp = xmax
        xold1 = xval
        xold2 = xval

        Hbeta = 1
        if self.ft==0:
            xPhys=x.copy()
        elif self.ft==1:
            xTilde=x.copy()
            xPhys=1-np.exp(-Hbeta*xTilde)+xTilde*np.exp(-Hbeta)

        H,Hs = ut.DensityFilter_init(self.rmin,self.nelx,self.nely)

        k0 = 1
        kmin = 1e-3
        p = 3

        Nsample = 40000

        Xint, Wint, _, _, eleidx = ut.getquadpts(L=self.Lx,H=self.Ly,Nelmufem=self.nelx,Nelmvfem=self.nely,numElemU=self.nelx,numElemV=self.nely,numGauss=2,bdcode=1)
        input_dof,evenidx,oddidx = ut.generatedofcoord(nelx=self.nelx,nely=self.nely,L=self.Lx,H=self.Ly)
        Wint = np.squeeze(Wint)

        mesh = {'nelx':self.nelx,'nely':self.nely,'L':self.Lx/100,'H':self.Ly/100,\
        'eleidx':eleidx,'Xint':Xint/100,'input_dof':input_dof/100,'evenidx':evenidx,'oddidx':oddidx,'Nsample':Nsample}

        material = {'volfrac':self.volfrac, 'k': k0, 'kmin': kmin, 'p':p, 's':0.001*(100)**2/117.65}

        lr = 1e-3
        Nepoch = 10
        batch_size = 2000
        neuron = 86
        rff_dev = 1.32
        N_Layers = 4
        act_func = 'swish'
        N_input_rho = self.nelx*self.nely
        N_input_coord = 2
        trainParams={'lr':lr,'Nepoch':Nepoch,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}

        self.SModel_pr = sm_pr.SurrogateModel_primal()
        self.SModel_pr.updatemesh(mesh)
        self.SModel_pr.updatematerial(material)
        self.SModel_pr.updatetrainParams(trainParams)

        X_DBC = np.zeros((5000,2))
        X_DBC[:,0] = 0.
        X_DBC[:,1] = np.linspace(0,self.Ly/10,5000)

        # Set loop counter and gradient vectors
        loop=0
        loopbeta=0
        iter=0
        change=1
        dv = np.ones(self.nely*self.nelx)
        dc = np.ones(self.nely*self.nelx)
        start_time=time.time()
        while change>-1 and loop<=self.maxiter:
            loop=loop+1
            loopbeta=loopbeta+1
            iter += 1
            rho_int = xPhys[eleidx]

            data = {'rho_quad':rho_int,'DBC':X_DBC/100}
            if loop==1:
              trainParams={'lr':lr,'Nepoch':1000,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}
            else:
              trainParams={'lr':lr,'Nepoch':Nepoch,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}
            self.SModel_pr.updatetrainParams(trainParams)

            self.SModel_pr.updatetrainset(data)
            if loop==1:
                self.SModel_pr.initialize_model()

            self.SModel_pr.trainmodel(verbose=True)
            print('Train ends after %d epochs'%self.SModel_pr.Endepoch)

            self.SModel_pr.Model.save(folder_path+'model_pr/model_pr.h5')

            t = self.SModel_pr.Model.predict(input_dof/100)
            t = t*117.65

            ut.plotdesign(folder_path+'surrogate_result/','current_design',xPhys,nelx=self.nelx,nely=self.nely)
            ut.plotresult_contour(folder_path+'surrogate_result/','solution_T',input_dof,t,L=self.Lx,H=self.Ly)

            volume = np.sum(xPhys)/(self.nelx*self.nely)
            dv = np.ones(self.nely*self.nelx)/self.nelx/self.nely

            T_dx,T_dy = self.SModel_pr.nabla_T(ut.preprocess(Xint[:,0]/100),ut.preprocess(Xint[:,1]/100))
            F_GQ = (T_dx*(117.65/self.Lx))**2+(T_dy*(117.65/self.Lx))**2

            #calculate cost
            FW_c = np.squeeze(F_GQ)*Wint*(kmin+(k0-kmin)*rho_int**3)
            cost = np.sum(FW_c)

            #calculate sensitivity
            FW_dc = np.squeeze(F_GQ)*Wint
            FW_dc = np.reshape(FW_dc,(-1,4))
            FW_dc = np.sum(FW_dc,axis=1)
            dc[:][eleidx[0::4]] = FW_dc
            dc = -1/2*(3*(xPhys**(3-1))*(k0-kmin))*dc

            if iter==1:
                cost0 = cost
            if self.ft==0:
                dc[:] = np.asarray(H*(dc[np.newaxis].T/Hs))[:,0]
                dv[:] = np.asarray(H*(dv[np.newaxis].T/Hs))[:,0]
            elif self.ft==1:
                dx = Hbeta*np.exp(-Hbeta*xTilde)+np.exp(-Hbeta)
                dc[:] = np.asarray(H*((dc*dx)[np.newaxis].T/Hs))[:,0]
                dv[:] = np.asarray(H*((dv*dx)[np.newaxis].T/Hs))[:,0]

            xold2 = xold1.copy()
            xold1 = x.copy()
            g = volume/self.volfrac
            dg = dv/self.volfrac

            xmin = maximum(zeros([nn,]), xval-move)
            xmax = minimum(ones([nn,]), xval+move)
            [iyfree,xmma,xlow,xupp,alfa,beta,mma_b,mma_y,mma_z,ulam,mma_p,mma_q,p0,q0,uu,gradf,dsrch,hessf] = \
                mmasub(iter,mm,nn,geps,xval,
                    xmin, xmax, xold1,xold2,xlow,xupp,
                    mma_a,mma_c,cost/cost0,g,fmax,dc/cost0, dg)
            xold2 = xold1
            xold1 = xval
            xval = xmma
            x[:] = xmma


            if self.ft==0:	xPhys[:]=np.asarray(H*x[np.newaxis].T/Hs)[:,0]
            elif self.ft==1:
                xTilde[:] = np.asarray(H*x[np.newaxis].T/Hs)[:,0]
                xPhys[:] = 1-np.exp(-Hbeta*xTilde)+xTilde*np.exp(-Hbeta)
            change=np.abs(xmma-xold1).max()

            if self.ft==1 and Hbeta<512 and loopbeta >=50:# or change<=0.01):
                Hbeta = 2*Hbeta
                loopbeta = 0
                change = 1
                print('Parameter beta increased to %d.\n'%Hbeta)

            if loop>1:
                del fig, ax

            fig,ax = plt.subplots()
            im = ax.imshow(xPhys.reshape((self.nelx,self.nely)).T, cmap='gray_r',\
            interpolation='none',norm=colors.Normalize(vmin=0,vmax=1))
            fig.show()
            fig.canvas.draw()

            if loop%1==0:
                plt.savefig(folder_path+'TOdesign/design%d.png'%(loop))
                plt.close('all')
                np.savetxt(folder_path+'TOdesign/design%d.txt'%(loop),xPhys)

            print("it.: {0} , obj.: {1:.3f} Vol.: {2:.3f}, ch.: {3:.3f}".format(\
                        loop,cost,volume,change))

            gc.collect()

        end_time=time.time()-start_time
        print('total time is: ', end_time)
        plt.show()

    def mmaInit(self, m, n, volfrac):
        move = 0.5 # move limit
        geps = 1e-9  # 1e-7

        xmin = zeros([n,]) # 0.001*ones([3,])
        xmax= ones([n,])
        # xval = volfrac*ones([n,])
        xval = ones([n,])*self.x_init

        # vol/volfrac < 1 where RHS is fmax
        fmax = 1.*ones([m,])

        mma_a = 0.*ones([m,])
        mma_c = 1000.*ones([m,])

        return geps,xval,move, xmin,xmax,fmax,mma_a,mma_c


    def __call__(self):
        self.optimize()

# %%
to2d= TO2D_heat(Lx=100,Ly=50,nelx=200,nely=100,filter=0,rmin=4.2,volfrac=0.5,x_init=0.5,maxiter=500)
to2d.optimize()
# Out:
# 2D TO for heat sink
# Number of nodes: 200 x 100
# Volume fraction: 0.5, rmin: 4.2
# Filter method: Density based
# Epoch 50:
# lr: 1.00e-03
# Data=4.8122e-04,               PDE=-9.0090e-03,               total_loss=-8.5278e-03
# Epoch 100:
# lr: 1.00e-03
# Data=6.9109e-04,               PDE=-1.2727e-02,               total_loss=-1.2036e-02
# Epoch 150:
# lr: 1.00e-03
# Data=5.8046e-04,               PDE=-1.3647e-02,               total_loss=-1.3066e-02
# Epoch 200:
# lr: 1.00e-03
# Data=5.7232e-04,               PDE=-1.3549e-02,               total_loss=-1.2976e-02
# Epoch 250:
# lr: 1.00e-03
# Data=6.3315e-04,               PDE=-1.3313e-02,               total_loss=-1.2680e-02
# Epoch 300:
# lr: 1.00e-03
# Data=5.9422e-04,               PDE=-1.3717e-02,               total_loss=-1.3122e-02
# Epoch 350:
# lr: 1.00e-03
# Data=5.7942e-04,               PDE=-1.3468e-02,               total_loss=-1.2888e-02
# Epoch 400:
# lr: 1.00e-03
# Data=6.8104e-04,               PDE=-1.3722e-02,               total_loss=-1.3041e-02
# Epoch 450:
# lr: 1.00e-03
# Data=5.1861e-04,               PDE=-1.4184e-02,               total_loss=-1.3666e-02
# Epoch 500:
# lr: 1.00e-03
# Data=6.5477e-04,               PDE=-1.4014e-02,               total_loss=-1.3359e-02
# Epoch 550:
# lr: 1.00e-03
# Data=6.1366e-04,               PDE=-1.4117e-02,               total_loss=-1.3503e-02
# Epoch 600:
# lr: 1.00e-03
# Data=5.7914e-04,               PDE=-1.4165e-02,               total_loss=-1.3586e-02
# Epoch 650:
# lr: 1.00e-03
# Data=5.9731e-04,               PDE=-1.4169e-02,               total_loss=-1.3572e-02
# Epoch 700:
# lr: 1.00e-03
# Data=6.7701e-04,               PDE=-1.3832e-02,               total_loss=-1.3155e-02
# Epoch 750:
# lr: 1.00e-03
# Data=6.6673e-04,               PDE=-1.4246e-02,               total_loss=-1.3579e-02
# Epoch 800:
# lr: 1.00e-03
# Data=6.3146e-04,               PDE=-1.3258e-02,               total_loss=-1.2626e-02
# Epoch 850:
# lr: 1.00e-03
# Data=7.4874e-04,               PDE=-1.3288e-02,               total_loss=-1.2540e-02
# Epoch 900:
# lr: 1.00e-03
# Data=6.3214e-04,               PDE=-1.3979e-02,               total_loss=-1.3346e-02
# Epoch 950:
# lr: 1.00e-03
# Data=6.4342e-04,               PDE=-1.3633e-02,               total_loss=-1.2990e-02
# Epoch 1000:
# lr: 1.00e-03
# Data=5.3571e-04,               PDE=-1.5396e-02,               total_loss=-1.4860e-02
# Train ends after 1000 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 1 , obj.: 424.632 Vol.: 0.500, ch.: 0.446
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 2 , obj.: 182.168 Vol.: 0.444, ch.: 0.172
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 3 , obj.: 117.182 Vol.: 0.480, ch.: 0.087
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 4 , obj.: 97.978 Vol.: 0.494, ch.: 0.082
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 5 , obj.: 95.866 Vol.: 0.497, ch.: 0.074
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 6 , obj.: 91.406 Vol.: 0.498, ch.: 0.073
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 7 , obj.: 86.106 Vol.: 0.498, ch.: 0.060
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 8 , obj.: 87.027 Vol.: 0.499, ch.: 0.057
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 9 , obj.: 87.255 Vol.: 0.499, ch.: 0.052
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 10 , obj.: 80.449 Vol.: 0.499, ch.: 0.053
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 11 , obj.: 82.843 Vol.: 0.499, ch.: 0.048
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 12 , obj.: 68.603 Vol.: 0.499, ch.: 0.047
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 13 , obj.: 83.854 Vol.: 0.499, ch.: 0.047
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 14 , obj.: 84.322 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 15 , obj.: 82.979 Vol.: 0.499, ch.: 0.051
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 16 , obj.: 72.791 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 17 , obj.: 78.439 Vol.: 0.500, ch.: 0.051
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 18 , obj.: 81.248 Vol.: 0.500, ch.: 0.055
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 19 , obj.: 75.766 Vol.: 0.500, ch.: 0.062
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 20 , obj.: 72.938 Vol.: 0.500, ch.: 0.057
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 21 , obj.: 72.365 Vol.: 0.500, ch.: 0.060
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 22 , obj.: 79.680 Vol.: 0.500, ch.: 0.055
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 23 , obj.: 70.996 Vol.: 0.500, ch.: 0.082
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 24 , obj.: 73.998 Vol.: 0.500, ch.: 0.054
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 25 , obj.: 76.669 Vol.: 0.499, ch.: 0.044
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 26 , obj.: 72.714 Vol.: 0.500, ch.: 0.058
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 27 , obj.: 71.954 Vol.: 0.499, ch.: 0.058
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 28 , obj.: 72.529 Vol.: 0.499, ch.: 0.063
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 29 , obj.: 68.191 Vol.: 0.499, ch.: 0.050
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 30 , obj.: 85.035 Vol.: 0.499, ch.: 0.066
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 31 , obj.: 68.498 Vol.: 0.500, ch.: 0.058
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 32 , obj.: 73.851 Vol.: 0.500, ch.: 0.046
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 33 , obj.: 77.525 Vol.: 0.500, ch.: 0.045
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 34 , obj.: 74.543 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 35 , obj.: 69.682 Vol.: 0.500, ch.: 0.040
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 36 , obj.: 63.974 Vol.: 0.500, ch.: 0.063
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.:
Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 213 , obj.: 56.592 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 214 , obj.: 61.886 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 215 , obj.: 61.568 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 216 , obj.: 64.205 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 217 , obj.: 64.847 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 218 , obj.: 67.763 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 219 , obj.: 65.230 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 220 , obj.: 61.145 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 221 , obj.: 60.239 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 222 , obj.: 63.778 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 223 , obj.: 63.564 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 224 , obj.: 60.814 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 225 , obj.: 60.044 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 226 , obj.: 63.035 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 227 , obj.: 66.954 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 228 , obj.: 61.730 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 229 , obj.: 61.270 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 230 , obj.: 61.636 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 231 , obj.: 64.937 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 232 , obj.: 56.257 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 233 , obj.: 62.437 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 234 , obj.: 61.846 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 235 , obj.: 63.588 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 236 , obj.: 68.367 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 237 , obj.: 58.945 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 238 , obj.: 58.017 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 239 , obj.: 59.607 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 240 , obj.: 62.804 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 241 , obj.: 64.106 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 242 , obj.: 59.196 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 243 , obj.: 62.792 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 244 , obj.: 64.262 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 245 , obj.: 65.345 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 246 , obj.: 62.738 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 247 , obj.: 58.378 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 248 , obj.: 66.741 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 249 , obj.: 64.311 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 250 , obj.: 60.776 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 251 , obj.: 65.982 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 252 , obj.: 62.004 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 253 , obj.: 63.360 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 254 , obj.: 64.426 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 255 , obj.: 57.423 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 256 , obj.: 63.126 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 257 , obj.: 68.466 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 258 , obj.: 55.156 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 259 , obj.: 66.207 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 260 , obj.: 66.354 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 261 , obj.: 66.583 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 262 , obj.: 65.502 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 263 , obj.: 62.563 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 264 , obj.: 62.106 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 265 , obj.: 61.057 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 2ms/step
# it.: 266 , obj.: 58.568 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 267 , obj.: 55.464 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 268 , obj.: 59.081 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 269 , obj.: 62.918 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 270 , obj.: 57.362 Vol.: 0.500, ch.: 0.046
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 271 , obj.: 66.082 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 272 , obj.: 61.675 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 273 , obj.: 65.235 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 274 , obj.: 60.224 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 275 , obj.: 63.396 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 276 , obj.: 61.145 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 277 , obj.: 58.893 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 278 , obj.: 62.442 Vol.: 0.500, ch.: 0.055
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 279 , obj.: 63.740 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 280 , obj.: 58.294 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 281 , obj.: 59.255 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 282 , obj.: 60.349 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 283 , obj.: 60.151 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 2ms/step
# it.: 284 , obj.: 59.577 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 285 , obj.: 67.947 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 286 , obj.: 66.092 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 287 , obj.: 60.703 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 288 , obj.: 66.788 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 289 , obj.: 58.612 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 290 , obj.: 60.598 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 2ms/step
# it.: 291 , obj.: 61.748 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 292 , obj.: 67.038 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 293 , obj.: 58.783 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 294 , obj.: 62.898 Vol.: 0.500, ch.: 0.052
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 295 , obj.: 54.885 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 296 , obj.: 59.240 Vol.: 0.500, ch.: 0.057
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 297 , obj.: 61.845 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 298 , obj.: 58.775 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 299 , obj.: 63.748 Vol.: 0.500, ch.: 0.051
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 300 , obj.: 63.849 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 301 , obj.: 65.724 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 302 , obj.: 59.456 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 303 , obj.: 59.199 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 304 , obj.: 61.235 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 305 , obj.: 62.556 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 306 , obj.: 62.099 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 307 , obj.: 61.940 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 308 , obj.: 63.963 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 309 , obj.: 64.376 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 310 , obj.: 67.837 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 311 , obj.: 58.151 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 312 , obj.: 60.518 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 313 , obj.: 58.732 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 314 , obj.: 63.939 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 315 , obj.: 62.376 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 316 , obj.: 65.995 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 317 , obj.: 57.106 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 318 , obj.: 60.613 Vol.: 0.500, ch.: 0.056
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 319 , obj.: 58.303 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 320 , obj.: 62.682 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 321 , obj.: 62.507 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 322 , obj.: 60.916 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 323 , obj.: 61.045 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 324 , obj.: 60.147 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 325 , obj.: 63.865 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 326 , obj.: 63.150 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 327 , obj.: 66.040 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 328 , obj.: 62.671 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 329 , obj.: 62.330 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 330 , obj.: 59.668 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 331 , obj.: 67.352 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 332 , obj.: 57.954 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 333 , obj.: 61.706 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 334 , obj.: 58.695 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 335 , obj.: 61.673 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 336 , obj.: 61.986 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 337 , obj.: 59.646 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 338 , obj.: 62.058 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 339 , obj.: 60.623 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 340 , obj.: 61.383 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 341 , obj.: 64.832 Vol.: 0.500, ch.: 0.046
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 342 , obj.: 60.135 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 343 , obj.: 65.521 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 344 , obj.: 57.272 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 345 , obj.: 65.098 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 346 , obj.: 59.453 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 347 , obj.: 60.894 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 348 , obj.: 56.658 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 349 , obj.: 61.624 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 350 , obj.: 61.546 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 351 , obj.: 63.237 Vol.: 0.500, ch.: 0.046
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 352 , obj.: 60.492 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# ...
# 635/635 [==============================] - 1s 1ms/step
# it.: 379 , obj.: 57.278 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 380 , obj.: 63.768 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 381 , obj.: 59.846 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 382 , obj.: 64.803 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 383 , obj.: 62.724 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 384 , obj.: 65.898 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 385 , obj.: 60.978 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 386 , obj.: 56.856 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 387 , obj.: 66.207 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 388 , obj.: 61.195 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 389 , obj.: 59.985 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 390 , obj.: 57.998 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 391 , obj.: 63.292 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 392 , obj.: 61.202 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 393 , obj.: 61.215 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 394 , obj.: 55.917 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 395 , obj.: 60.327 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 396 , obj.: 60.484 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 397 , obj.: 58.005 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 398 , obj.: 60.019 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 399 , obj.: 63.061 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 400 , obj.: 60.511 Vol.: 0.500, ch.: 0.046
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 401 , obj.: 57.918 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 402 , obj.: 62.748 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 403 , obj.: 59.299 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 404 , obj.: 60.061 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 405 , obj.: 65.960 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 406 , obj.: 65.647 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 407 , obj.: 62.158 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 408 , obj.: 64.998 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 409 , obj.: 63.337 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 410 , obj.: 60.568 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 411 , obj.: 66.484 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 412 , obj.: 59.602 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 413 , obj.: 59.377 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 414 , obj.: 66.544 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 415 , obj.: 68.280 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 416 , obj.: 60.813 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 417 , obj.: 57.561 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 418 , obj.: 64.526 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 419 , obj.: 59.730 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 420 , obj.: 69.991 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 421 , obj.: 65.129 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 2ms/step
# it.: 422 , obj.: 60.732 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 423 , obj.: 59.732 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 424 , obj.: 58.384 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 425 , obj.: 65.606 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 426 , obj.: 56.317 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 427 , obj.: 60.593 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 428 , obj.: 60.958 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 429 , obj.: 65.060 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 430 , obj.: 63.043 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 431 , obj.: 65.616 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 432 , obj.: 61.396 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 433 , obj.: 64.539 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 434 , obj.: 59.950 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 435 , obj.: 62.202 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 436 , obj.: 56.298 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 437 , obj.: 64.658 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 438 , obj.: 61.982 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 439 , obj.: 56.051 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 440 , obj.: 61.867 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 441 , obj.: 59.050 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 442 , obj.: 60.264 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 443 , obj.: 62.027 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 444 , obj.: 60.829 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 445 , obj.: 57.756 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 446 , obj.: 59.282 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 447 , obj.: 59.901 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 448 , obj.: 62.507 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 449 , obj.: 62.103 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 450 , obj.: 61.940 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 451 , obj.: 59.230 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 452 , obj.: 67.389 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 453 , obj.: 62.618 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 454 , obj.: 61.202 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 455 , obj.: 63.702 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 456 , obj.: 64.111 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 457 , obj.: 57.398 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 458 , obj.: 54.768 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 459 , obj.: 58.470 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 460 , obj.: 63.457 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 461 , obj.: 62.892 Vol.: 0.500, ch.: 0.046
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 462 , obj.: 57.144 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 463 , obj.: 59.089 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 464 , obj.: 65.569 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 465 , obj.: 68.325 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 466 , obj.: 60.275 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 467 , obj.: 61.004 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 468 , obj.: 53.231 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 469 , obj.: 58.231 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 470 , obj.: 61.091 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 471 , obj.: 60.402 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 472 , obj.: 57.098 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 473 , obj.: 58.555 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 474 , obj.: 59.954 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 475 , obj.: 60.156 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 476 , obj.: 59.447 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 477 , obj.: 65.910 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 478 , obj.: 63.814 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 479 , obj.: 62.023 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 480 , obj.: 69.838 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 481 , obj.: 65.561 Vol.: 0.500, ch.: 0.040
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 482 , obj.: 62.007 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 483 , obj.: 59.451 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 484 , obj.: 57.300 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 485 , obj.: 62.275 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 486 , obj.: 58.921 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 487 , obj.: 61.195 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 2ms/step
# it.: 488 , obj.: 62.074 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 489 , obj.: 69.988 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 490 , obj.: 66.104 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 491 , obj.: 62.471 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 492 , obj.: 72.895 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 493 , obj.: 61.320 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 494 , obj.: 60.130 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 495 , obj.: 60.132 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 496 , obj.: 65.334 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 497 , obj.: 63.309 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 498 , obj.: 67.237 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 499 , obj.: 64.338 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 500 , obj.: 54.559 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 635/635 [==============================] - 1s 1ms/step
# it.: 501 , obj.: 63.967 Vol.: 0.500, ch.: 0.035
# total time is:  4523.655006885529
