# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import standard packages
from __future__ import division
from numpy import *
import numpy as np
from scipy.sparse import coo_matrix
from matplotlib import colors
import matplotlib.pyplot as plt
import tensorflow as tf
import sys
import time
import os
import gc
import warnings

# %%
# install necessary packages
# !pip install tf_fourier_features
# !pip install geomdl

# %%
warnings.filterwarnings("ignore")

# %%
# path of current folder
folder_path = '/content/drive/MyDrive/DEM_TO/Heat_100_50/'
# add the path to python's search list
sys.path.append(folder_path)
sys.path.append(folder_path+'UtilityFunctions/')

# %%
# import self-defined modules
import utils as ut
import surrogate_model_primal as sm_pr
from mma import mmasub

# %%
# use gpu for tensorflow
if tf.config.list_physical_devices('GPU'):
  physical_devices = tf.config.list_physical_devices('GPU')
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
  print('Using GPU')
else:
  print('Using CPU')
# Out:
# Using GPU

# %%
ut.makepath(folder_path+'TOdesign')
ut.makepath(folder_path+'surrogate_result')
ut.makepath(folder_path+'model_pr')
# Out:
# '/content/drive/MyDrive/DEM_TO/Heat_100_50/surrogate_result/'

# %%
class TO2D_heat():
    # Initialization of the class with default parameters
    def __init__(self,Lx=100,Ly=50,nelx=100,nely=50,volfrac=0.5,rmin=3,maxiter=1000,filter=0,x_init=0.5):
        # Class parameters
        self.Lx = Lx
        self.Ly = Ly
        self.nelx = nelx
        self.nely = nely
        self.volfrac = volfrac
        self.rmin = rmin
        self.maxiter = maxiter
        self.ft = filter
        self.x_init = x_init* np.ones(self.nely*self.nelx,dtype=float)

        # Initialization message
        print("2D TO for heat sink")
        print("Number of nodes: " + str(self.nelx) + " x " + str(self.nely))
        print("Volume fraction: " + str(self.volfrac) + ", rmin: " + str(self.rmin))
        print("Filter method: " + ["Density based","Density based + Heaviside filter"][self.ft])

    # Main topology optimization routine
    def optimize(self):

        # initialize design variable and MMA paramters
        x = self.x_init.copy()
        nn = len(x)
        mm = 1
        [geps,xval,move,xmin,xmax,fmax,mma_a,mma_c] = self.mmaInit(mm, nn, self.volfrac)
        xlow = xmin
        xupp = xmax
        xold1 = xval
        xold2 = xval

        # initialize the physical density vector
        Hbeta = 1
        if self.ft==0:
            xPhys=x.copy()
        elif self.ft==1:
            xTilde=x.copy()
            xPhys=1-np.exp(-Hbeta*xTilde)+xTilde*np.exp(-Hbeta)

        # ut.DensityFilter_init gives the H and Hs for density filtering
        H,Hs = ut.DensityFilter_init(self.rmin,self.nelx,self.nely)

        # set the material properties
        k0 = 1
        kmin = 1e-3
        p = 3
        material = {'volfrac':self.volfrac, 'k': k0, 'kmin': kmin, 'p':p, 's':0.001*(100)**2/117.65}

        # obtain the gaussian quadrature points
        Xint, Wint, _, _, eleidx = ut.getquadpts(L=self.Lx,H=self.Ly,Nelmufem=self.nelx,Nelmvfem=self.nely,numElemU=self.nelx,numElemV=self.nely,numGauss=2,bdcode=1)
        # obtain the TO mesh nodes
        input_dof,evenidx,oddidx = ut.generatedofcoord(nelx=self.nelx,nely=self.nely,L=self.Lx,H=self.Ly)
        Wint = np.squeeze(Wint)
        # Nsample is the number of randomly sampled traning points (For Monte-Carlo integration)
        Nsample = 40000

        mesh = {'nelx':self.nelx,'nely':self.nely,'L':self.Lx/100,'H':self.Ly/100,\
        'eleidx':eleidx,'Xint':Xint/100,'input_dof':input_dof/100,'evenidx':evenidx,'oddidx':oddidx,'Nsample':Nsample}

        # nueral network model paramters
        lr = 1e-3
        Nepoch = 10
        batch_size = 2000
        neuron = 86
        rff_dev = 1.32
        N_Layers = 4
        act_func = 'swish'
        N_input_rho = self.nelx*self.nely
        N_input_coord = 2
        trainParams={'lr':lr,'Nepoch':Nepoch,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}

        # initialize the surrogate model for primal equation
        self.SModel_pr = sm_pr.SurrogateModel_primal()
        self.SModel_pr.updatemesh(mesh)
        self.SModel_pr.updatematerial(material)
        self.SModel_pr.updatetrainParams(trainParams)

        # set the boundary condition training points
        X_DBC = np.zeros((5000,2))
        X_DBC[:,0] = 0.
        X_DBC[:,1] = np.linspace(0,self.Ly/10,5000)

        # Set loop counter and initialize gradient vectors
        loop=0
        loopbeta=0
        iter=0
        change=1
        dv = np.ones(self.nely*self.nelx)
        dc = np.ones(self.nely*self.nelx)
        start_time=time.time()
        # main topology optimization loop
        while change>-1 and loop<=self.maxiter:  # loop until maxiter is reached
            loop=loop+1
            loopbeta=loopbeta+1
            iter += 1

            rho_int = xPhys[eleidx] # rho_int is the value of density at gaussian quadrature points
            data = {'rho_quad':rho_int,'DBC':X_DBC/100}

            if loop==1:
              # if TO iteration=1, train longer, Nepoch=1000
              trainParams={'lr':lr,'Nepoch':1000,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}
            else:
              # other wise Nepoch=10
              trainParams={'lr':lr,'Nepoch':Nepoch,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}
            # update the train parameters to primal surrogate model
            self.SModel_pr.updatetrainParams(trainParams)
            self.SModel_pr.updatetrainset(data)

            if loop==1:
                # if TO iteration=1, initialize the neural network model
                self.SModel_pr.initialize_model()


            # train the neural network model
            self.SModel_pr.trainmodel(verbose=True)
            print('Train ends after %d epochs'%self.SModel_pr.Endepoch)

            # save the model
            self.SModel_pr.Model.save(folder_path+'model_pr/model_pr.h5')

            # pass TO mesh nodes' coordinates to neural network, get the temperature
            t = self.SModel_pr.Model.predict(input_dof/100)
            t = t*117.65

            # plot the current design and solution
            ut.plotdesign(folder_path+'surrogate_result/','current_design',xPhys,nelx=self.nelx,nely=self.nely)
            ut.plotresult_contour(folder_path+'surrogate_result/','solution_T',input_dof,t,L=self.Lx,H=self.Ly)

            # calculate the volume and volume constraint sensitivity
            volume = np.sum(xPhys)/(self.nelx*self.nely)
            dv = np.ones(self.nely*self.nelx)/self.nelx/self.nely

            # calculate the spatial gradients by AD
            T_dx,T_dy = self.SModel_pr.nabla_T(ut.preprocess(Xint[:,0]/100),ut.preprocess(Xint[:,1]/100))
            F_GQ = (T_dx*(117.65/self.Lx))**2+(T_dy*(117.65/self.Lx))**2
            #calculate cost
            FW_c = np.squeeze(F_GQ)*Wint*(kmin+(k0-kmin)*rho_int**3)
            cost = np.sum(FW_c)
            #calculate sensitivity
            FW_dc = np.squeeze(F_GQ)*Wint
            FW_dc = np.reshape(FW_dc,(-1,4))
            FW_dc = np.sum(FW_dc,axis=1)
            dc[:][eleidx[0::4]] = FW_dc
            dc = -1/2*(3*(xPhys**(3-1))*(k0-kmin))*dc

            if iter==1:
                cost0 = cost
            if self.ft==0:
                # if use density filter, the sensitivity...
                dc[:] = np.asarray(H*(dc[np.newaxis].T/Hs))[:,0]
                dv[:] = np.asarray(H*(dv[np.newaxis].T/Hs))[:,0]
            elif self.ft==1:
                # if use density+heaviside filter, the sensitivity...
                dx = Hbeta*np.exp(-Hbeta*xTilde)+np.exp(-Hbeta)
                dc[:] = np.asarray(H*((dc*dx)[np.newaxis].T/Hs))[:,0]
                dv[:] = np.asarray(H*((dv*dx)[np.newaxis].T/Hs))[:,0]

            xold2 = xold1.copy()
            xold1 = x.copy()
            g = volume/self.volfrac
            dg = dv/self.volfrac

            # mma gives design update
            xmin = maximum(zeros([nn,]), xval-move)
            xmax = minimum(ones([nn,]), xval+move)
            [iyfree,xmma,xlow,xupp,alfa,beta,mma_b,mma_y,mma_z,ulam,mma_p,mma_q,p0,q0,uu,gradf,dsrch,hessf] = \
                mmasub(iter,mm,nn,geps,xval,
                    xmin, xmax, xold1,xold2,xlow,xupp,
                    mma_a,mma_c,cost/cost0,g,fmax,dc/cost0, dg)
            xold2 = xold1
            xold1 = xval
            xval = xmma
            x[:] = xmma

            # filter the updated design
            if self.ft==0:	xPhys[:]=np.asarray(H*x[np.newaxis].T/Hs)[:,0]
            elif self.ft==1:
                xTilde[:] = np.asarray(H*x[np.newaxis].T/Hs)[:,0]
                xPhys[:] = 1-np.exp(-Hbeta*xTilde)+xTilde*np.exp(-Hbeta)
            change=np.abs(xmma-xold1).max()

            # if use heaviside filter, beta need to increase
            if self.ft==1 and Hbeta<512 and loopbeta >=50:# or change<=0.01):
                Hbeta = 2*Hbeta
                loopbeta = 0
                change = 1
                print('Parameter beta increased to %d.\n'%Hbeta)

            if loop>1:
                del fig, ax

            # save the TO design to folder
            fig,ax = plt.subplots()
            im = ax.imshow(xPhys.reshape((self.nelx,self.nely)).T, cmap='gray_r',\
            interpolation='none',norm=colors.Normalize(vmin=0,vmax=1))
            fig.show()
            fig.canvas.draw()
            if loop%1==0:
                plt.savefig(folder_path+'TOdesign/design%d.png'%(loop))
                plt.close('all')
                np.savetxt(folder_path+'TOdesign/design%d.txt'%(loop),xPhys)

            # print the outcome of this TO iteration
            print("it.: {0} , obj.: {1:.3f} Vol.: {2:.3f}, ch.: {3:.3f}".format(\
                        loop,cost,volume,change))

            gc.collect()

        end_time=time.time()-start_time
        print('total time is: ', end_time)
        plt.show()

    def mmaInit(self, m, n, volfrac): # function to initilize mma
        move = 0.5 # move limit
        geps = 1e-9  # 1e-7

        xmin = zeros([n,]) # 0.001*ones([3,])
        xmax= ones([n,])
        # xval = volfrac*ones([n,])
        xval = ones([n,])*self.x_init

        # vol/volfrac < 1 where RHS is fmax
        fmax = 1.*ones([m,])

        mma_a = 0.*ones([m,])
        mma_c = 1000.*ones([m,])

        return geps,xval,move, xmin,xmax,fmax,mma_a,mma_c


    def __call__(self):
        self.optimize()

# %%
# initialize the clasee to2d and then conduct TO
to2d= TO2D_heat(Lx=100,Ly=50,nelx=100,nely=50,filter=0,rmin=4.2,volfrac=0.5,x_init=0.5,maxiter=500)
to2d.optimize()
# Out:
# 2D TO for heat sink
# Number of nodes: 100 x 50
# Volume fraction: 0.5, rmin: 4.2
# Filter method: Density based
# Epoch 50:
# lr: 1.00e-03
# Data=5.4876e-04,               PDE=-1.0143e-02,               total_loss=-9.5946e-03
# Epoch 100:
# lr: 1.00e-03
# Data=6.9402e-04,               PDE=-1.2730e-02,               total_loss=-1.2036e-02
# Epoch 150:
# lr: 1.00e-03
# Data=6.0022e-04,               PDE=-1.3907e-02,               total_loss=-1.3306e-02
# Epoch 200:
# lr: 1.00e-03
# Data=6.1251e-04,               PDE=-1.3490e-02,               total_loss=-1.2877e-02
# Epoch 250:
# lr: 1.00e-03
# Data=7.1226e-04,               PDE=-1.3115e-02,               total_loss=-1.2403e-02
# Epoch 300:
# lr: 1.00e-03
# Data=6.5106e-04,               PDE=-1.3925e-02,               total_loss=-1.3274e-02
# Epoch 350:
# lr: 1.00e-03
# Data=6.9482e-04,               PDE=-1.3543e-02,               total_loss=-1.2848e-02
# Epoch 400:
# lr: 1.00e-03
# Data=6.5048e-04,               PDE=-1.4278e-02,               total_loss=-1.3628e-02
# Epoch 450:
# lr: 1.00e-03
# Data=6.6151e-04,               PDE=-1.4454e-02,               total_loss=-1.3793e-02
# Epoch 500:
# lr: 1.00e-03
# Data=7.3692e-04,               PDE=-1.3363e-02,               total_loss=-1.2626e-02
# Epoch 550:
# lr: 1.00e-03
# Data=6.0479e-04,               PDE=-1.4451e-02,               total_loss=-1.3846e-02
# Epoch 600:
# lr: 1.00e-03
# Data=6.2519e-04,               PDE=-1.4291e-02,               total_loss=-1.3666e-02
# Epoch 650:
# lr: 1.00e-03
# Data=6.3169e-04,               PDE=-1.4248e-02,               total_loss=-1.3617e-02
# Epoch 700:
# lr: 1.00e-03
# Data=7.5990e-04,               PDE=-1.4045e-02,               total_loss=-1.3285e-02
# Epoch 750:
# lr: 1.00e-03
# Data=7.4387e-04,               PDE=-1.4046e-02,               total_loss=-1.3302e-02
# Epoch 800:
# lr: 1.00e-03
# Data=6.5092e-04,               PDE=-1.3767e-02,               total_loss=-1.3116e-02
# Epoch 850:
# lr: 1.00e-03
# Data=5.9278e-04,               PDE=-1.3469e-02,               total_loss=-1.2877e-02
# Epoch 900:
# lr: 1.00e-03
# Data=6.1224e-04,               PDE=-1.4317e-02,               total_loss=-1.3705e-02
# Epoch 950:
# lr: 1.00e-03
# Data=5.9002e-04,               PDE=-1.4657e-02,               total_loss=-1.4067e-02
# Epoch 1000:
# lr: 1.00e-03
# Data=5.4905e-04,               PDE=-1.4478e-02,               total_loss=-1.3929e-02
# Train ends after 1000 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.:
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 43 , obj.: 70.875 Vol.: 0.500, ch.: 0.047
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 44 , obj.: 66.443 Vol.: 0.500, ch.: 0.050
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 45 , obj.: 66.126 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 46 , obj.: 73.449 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 47 , obj.: 64.434 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 48 , obj.: 71.924 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 49 , obj.: 74.108 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 50 , obj.: 66.120 Vol.: 0.500, ch.: 0.048
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 51 , obj.: 65.430 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 52 , obj.: 66.687 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 53 , obj.: 60.392 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 54 , obj.: 65.304 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 55 , obj.: 64.540 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 56 , obj.: 69.360 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 57 , obj.: 61.566 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 58 , obj.: 69.222 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 59 , obj.: 72.612 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 60 , obj.: 69.862 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 61 , obj.: 67.604 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 62 , obj.: 59.795 Vol.: 0.500, ch.: 0.041
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 63 , obj.: 66.549 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 64 , obj.: 78.153 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 65 , obj.: 61.694 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 66 , obj.: 63.976 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 67 , obj.: 62.787 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 68 , obj.: 74.500 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 69 , obj.: 68.563 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 70 , obj.: 63.840 Vol.: 0.500, ch.: 0.043
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 71 , obj.: 72.403 Vol.: 0.500, ch.: 0.050
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 72 , obj.: 69.694 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 73 , obj.: 67.847 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 74 , obj.: 70.610 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 75 , obj.: 67.082 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 76 , obj.: 67.798 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 77 , obj.: 62.769 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 78 , obj.: 68.269 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 79 , obj.: 58.706 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 80 , obj.: 65.434 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 81 , obj.: 67.384 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 82 , obj.: 72.783 Vol.: 0.500, ch.: 0.049
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 83 , obj.: 64.730 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 84 , obj.: 76.216 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 85 , obj.: 65.152 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 86 , obj.: 73.471 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 87 , obj.: 59.095 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 88 , obj.: 65.493 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 89 , obj.: 68.771 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 90 , obj.: 62.039 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 91 , obj.: 66.929 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 92 , obj.: 61.926 Vol.: 0.500, ch.: 0.040
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 93 , obj.: 68.530 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 94 , obj.: 73.295 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 95 , obj.: 73.585 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 96 , obj.: 65.758 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 97 , obj.: 67.566 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 98 , obj.: 66.063 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 99 , obj.: 71.723 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 100 , obj.: 71.280 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 101 , obj.: 61.809 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 102 , obj.: 75.556 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 103 , obj.: 61.835 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 104 , obj.: 67.114 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 105 , obj.: 66.783 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 106 , obj.: 63.695 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 107 , obj.: 64.034 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 108 , obj.: 74.184 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 109 , obj.: 63.483 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 110 , obj.: 62.739 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.:
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 426 , obj.: 64.080 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 427 , obj.: 71.189 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 428 , obj.: 71.033 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 429 , obj.: 71.302 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 430 , obj.: 68.154 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 431 , obj.: 59.487 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 432 , obj.: 68.569 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 433 , obj.: 64.171 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 434 , obj.: 66.742 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 435 , obj.: 68.129 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 436 , obj.: 70.422 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 437 , obj.: 69.567 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 438 , obj.: 72.723 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 439 , obj.: 65.941 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 440 , obj.: 65.307 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 441 , obj.: 68.039 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 442 , obj.: 72.400 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 443 , obj.: 65.305 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 444 , obj.: 65.480 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 445 , obj.: 66.099 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 446 , obj.: 69.444 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 447 , obj.: 69.826 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 448 , obj.: 75.836 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 449 , obj.: 65.281 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 450 , obj.: 69.771 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 451 , obj.: 63.841 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 452 , obj.: 61.641 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 453 , obj.: 74.545 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 454 , obj.: 65.533 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 455 , obj.: 68.429 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 456 , obj.: 62.583 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 457 , obj.: 63.768 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 458 , obj.: 62.061 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 459 , obj.: 65.851 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 460 , obj.: 64.246 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 461 , obj.: 65.158 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 462 , obj.: 59.661 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 463 , obj.: 64.112 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 464 , obj.: 65.132 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 465 , obj.: 66.658 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 466 , obj.: 67.576 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 467 , obj.: 65.550 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 468 , obj.: 66.064 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 469 , obj.: 64.874 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 470 , obj.: 66.888 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 471 , obj.: 64.487 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 472 , obj.: 66.822 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 473 , obj.: 64.169 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 474 , obj.: 64.297 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 475 , obj.: 62.579 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 476 , obj.: 67.637 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 477 , obj.: 68.323 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 478 , obj.: 66.170 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 479 , obj.: 59.998 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 480 , obj.: 66.345 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 481 , obj.: 64.141 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 482 , obj.: 67.588 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 483 , obj.: 68.310 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 484 , obj.: 63.837 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 485 , obj.: 69.089 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 486 , obj.: 61.712 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 487 , obj.: 62.845 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 2ms/step
# it.: 488 , obj.: 60.452 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 489 , obj.: 63.502 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 490 , obj.: 64.945 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 491 , obj.: 66.616 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 492 , obj.: 65.902 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 493 , obj.: 65.651 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 494 , obj.: 61.152 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 495 , obj.: 64.226 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 496 , obj.: 64.402 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 497 , obj.: 61.212 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 498 , obj.: 66.648 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 499 , obj.: 65.630 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 500 , obj.: 54.270 Vol.: 0.500, ch.: 0.046
# Train ends after 10 epochs
# 161/161 [==============================] - 0s 1ms/step
# it.: 501 , obj.: 63.708 Vol.: 0.500, ch.: 0.018
# total time is:  3843.487683534622
