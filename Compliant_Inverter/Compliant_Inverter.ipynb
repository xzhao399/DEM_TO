# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install necessary packages
# !pip install tf_fourier_features
# !pip install geomdl

# %%
# import standard packages
from __future__ import division
from numpy import *
import numpy as np
from scipy.sparse import coo_matrix
from matplotlib import colors
import matplotlib.pyplot as plt
import tensorflow as tf
import sys
import time
import os
import gc
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
# path of current folder
folder_path = '/content/drive/MyDrive/DEM_TO/Compliant_Inverter/'
# add the path to python's search list
sys.path.append(folder_path)
sys.path.append(folder_path+'UtilityFunctions/')

# %%
# import custimized modules
import utils as ut
import surrogate_model_primal as sm_pr
import surrogate_model_adjoint as sm_ad
from mma import mmasub

# %%
# use gpu for tensorflow
if tf.config.list_physical_devices('GPU'):
  physical_devices = tf.config.list_physical_devices('GPU')
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
  print('Using GPU')
else:
  print('Using CPU')
# Out:
# Using GPU

# %%
ut.makepath(folder_path+'TOdesign')
ut.makepath(folder_path+'surrogate_result')
ut.makepath(folder_path+'model_pr')
ut.makepath(folder_path+'model_ad')
# Out:
# '/content/drive/MyDrive/DEM_TO/Compliant_Inverter/model_ad/'

# %%
class TO2D_CMInverter():
    def __init__(self,Lx=120,Ly=60,nelx=120,nely=60,volfrac=0.3,rmin=4.2,maxiter=1000,filter=0,x_init=0.3,pv=None,ps=None):
        self.Lx = Lx
        self.Ly = Ly
        self.nelx = nelx
        self.nely = nely
        self.volfrac = volfrac
        self.rmin = rmin
        self.maxiter = maxiter
        self.ft = filter
        self.x_init = x_init* np.ones(self.nely*self.nelx,dtype=float)
        self.passive_void = pv
        self.passive_solid = ps
        self.x_init[np.where(self.passive_void==1)] = 0.
        self.x_init[np.where(self.passive_solid==1)] = 1.
        print("2D TO for CM Inverter")
        print("Number of nodes: " + str(self.nelx) + " x " + str(self.nely))
        print("Volume fraction: " + str(self.volfrac) + ", rmin: " + str(self.rmin))
        print("Filter method: " + ["Density based","Density based + Heaviside filter"][self.ft])

    def optimize(self):
        x = self.x_init.copy()

        nn = len(x)
        mm = 1
        [geps,xval,move,xmin,xmax,fmax,mma_a,mma_c] = self.mmaInit(mm, nn, self.volfrac)
        xlow = xmin
        xupp = xmax
        xold1 = xval
        xold2 = xval

        Hbeta = 1
        if self.ft==0:
            xPhys=x.copy()
        elif self.ft==1:
            xTilde=x.copy()
            xPhys=1-np.exp(-Hbeta*xTilde)+xTilde*np.exp(-Hbeta)

        H,Hs = ut.DensityFilter_init(self.rmin,self.nelx,self.nely)

        Nsample = 40000

        Xint, Wint, _, _, eleidx = ut.getquadpts(L=self.Lx,H=self.Ly,Nelmufem=self.nelx,Nelmvfem=self.nely,numElemU=self.nelx,numElemV=self.nely,numGauss=2,bdcode=1)
        input_dof,evenidx,oddidx = ut.generatedofcoord(nelx=self.nelx,nely=self.nely,L=self.Lx,H=self.Ly)
        Wint = np.squeeze(Wint)

        rhoden = np.ones_like(Xint[:,0:1])*0.3

        mesh = {'nelx':self.nelx,'nely':self.nely,'L':self.Lx,'H':self.Ly,\
        'eleidx':eleidx,'Xint':Xint,'input_dof':input_dof,'evenidx':evenidx,'oddidx':oddidx,\
                'X_densified':Xint,'rho_densified':rhoden,'Nsample':Nsample}

        E=1
        Emin=1e-3
        nu=0.3
        k1=1
        k2=0.001
        p=3
        material = {'volfrac':self.volfrac,'E':E,'Emin':Emin,'nu':nu,'p':p,'k1':k1,'k2':k2,\
                    'lambda':1*nu/((1 + nu)*(1 - nu)),'mu':1/(2*(1 + nu))}

        lr = 1e-3
        Nepoch = 200
        batch_size = 2000
        neuron = 86
        rff_dev = 0.3
        N_Layers = 4
        act_func = 'swish'
        N_input_rho = self.nelx*self.nely
        N_input_coord = 2
        trainParams={'lr':lr,'Nepoch':Nepoch,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}

        self.SModel_pr = sm_pr.SurrogateModel_primal()
        self.SModel_pr.updatemesh(mesh)
        self.SModel_pr.updatematerial(material)
        self.SModel_pr.updatetrainParams(trainParams)

        self.SModel_ad = sm_ad.SurrogateModel_adjoint()
        self.SModel_ad.updatemesh(mesh)
        self.SModel_ad.updatematerial(material)
        self.SModel_ad.updatetrainParams(trainParams)

        transfer = tf.keras.models.Sequential([
        tf.keras.layers.ZeroPadding2D(padding=(1, 1), input_shape=(self.nelx, self.nely, 1)),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=1),])

        dof_coord = np.repeat(input_dof,2,axis=0)
        # input_dof_DBC1 = dof_coord[solver.fixed1,:]
        input_dof_DBC1 = np.zeros((1000,2))
        input_dof_DBC1[:,0] = 0.
        input_dof_DBC1[:,1] = np.linspace(0,self.Ly/30,1000)
        # input_dof_DBC2 = dof_coord[solver.fixed2,:]
        input_dof_DBC2 = np.zeros((1000,2))
        input_dof_DBC2[:,1] = self.Ly
        input_dof_DBC2[:,0] = np.linspace(0,self.Lx,1000)

        # Set loop counter and gradient vectors
        loop=0
        iter=0
        change=1
        dv = np.ones(self.nely*self.nelx)
        dc = np.ones(self.nely*self.nelx)
        start_time=time.time()

        while change>-1 and loop<=self.maxiter:
            loop=loop+1
            iter += 1

            x_res = xPhys.reshape((1,self.nelx,self.nely,1))
            x_res = np.array(transfer(x_res)).flatten()

            rhoden = xPhys[eleidx]

            data = {'rho':xPhys,'rho_quad':rhoden,'DBC1':input_dof_DBC1,'DBC2':input_dof_DBC2}

            if loop==1:
              trainParams={'lr':lr,'Nepoch':200,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}
            else:
              trainParams={'lr':lr,'Nepoch':Nepoch,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}
            self.SModel_pr.updatetrainParams(trainParams)
            self.SModel_ad.updatetrainParams(trainParams)

            self.SModel_pr.updatetrainset(data)
            self.SModel_ad.updatetrainset(data)
            if loop==1:
                self.SModel_pr.initialize_model()
                self.SModel_ad.initialize_model()

            self.SModel_pr.trainmodel(verbose=True)
            print('Train ends after %d epochs'%self.SModel_pr.Endepoch)
            if loop%1==0:
                self.SModel_pr.Model.save(folder_path+'model_pr/model_pr.h5')

            self.SModel_ad.trainmodel(verbose=True)
            print('Train ends after %d epochs'%self.SModel_ad.Endepoch)
            if loop%1==0:
                self.SModel_ad.Model.save(folder_path+'model_ad/model_ad.h5')

            u = np.ones(((self.nelx+1)*(self.nely+1)*2,1))
            U,V = self.SModel_pr.Model.predict(input_dof)
            u[evenidx,0]=np.squeeze(U)
            u[oddidx,0]=np.squeeze(V)

            lm = np.ones(((self.nelx+1)*(self.nely+1)*2,1))
            lm_x,lm_y = self.SModel_ad.Model.predict(input_dof)
            lm[evenidx,0]=np.squeeze(lm_x)
            lm[oddidx,0]=np.squeeze(lm_y)

            if loop%1==0:
                ut.plotdesign(folder_path+'surrogate_result/','current_design',xPhys,nelx=self.nelx,nely=self.nely)
                ut.plotresult_contour(folder_path+'surrogate_result/','solution_U',input_dof,U,L=self.Lx,H=self.Ly)
                ut.plotresult_contour(folder_path+'surrogate_result/','solution_V',input_dof,V,L=self.Lx,H=self.Ly)
                ut.plotresult_contour(folder_path+'surrogate_result/','solution_lambda_x',input_dof,lm_x,L=self.Lx,H=self.Ly)
                ut.plotresult_contour(folder_path+'surrogate_result/','solution_lambda_y',input_dof,lm_y,L=self.Lx,H=self.Ly)

            volume = np.sum(xPhys)/(self.nelx*self.nely)
            dv = np.ones(self.nely*self.nelx)/self.nelx/self.nely

            cost = -1*u[self.nelx*(self.nely+1)*2+2*self.nelx//5+1][0]
            psi_x_dx,psi_x_dy,psi_y_dx,psi_y_dy = self.SModel_ad.nabla_psi(ut.preprocess(Xint[:,0]),ut.preprocess(Xint[:,1]))
            sig_hat_xx,sig_hat_xy,sig_hat_yy = self.SModel_pr.sigma_hat(ut.preprocess(Xint[:,0]),ut.preprocess(Xint[:,1]))
            F_GQ = psi_x_dx*sig_hat_xx + psi_x_dy*sig_hat_xy+ psi_y_dx*sig_hat_xy+ psi_y_dy*sig_hat_yy
            FW = F_GQ*Wint
            FW = np.reshape(FW,(-1,4))
            dc_hat = np.sum(FW,axis=1)
            dc_hat1 = dc_hat.copy()
            dc_hat1[:][eleidx[0::4]] = dc_hat
            dc = -(3*xPhys**(3-1)*(E-Emin))*dc_hat1

            if self.ft==0:
                dc[:] = np.asarray(H*(dc[np.newaxis].T/Hs))[:,0]
                dv[:] = np.asarray(H*(dv[np.newaxis].T/Hs))[:,0]
            elif self.ft==1:
                dx = Hbeta*np.exp(-Hbeta*xTilde)+np.exp(-Hbeta)
                dc[:] = np.asarray(H*((dc*dx)[np.newaxis].T/Hs))[:,0]
                dv[:] = np.asarray(H*((dv*dx)[np.newaxis].T/Hs))[:,0]

            xold2 = xold1.copy()
            xold1 = x.copy()
            g = volume/self.volfrac
            dg = dv/self.volfrac

            xmin = maximum(zeros([nn,]), xval-move)
            xmax = minimum(ones([nn,]), xval+move)
            [iyfree,xmma,xlow,xupp,alfa,beta,mma_b,mma_y,mma_z,ulam,mma_p,mma_q,p0,q0,uu,gradf,dsrch,hessf] = \
                mmasub(iter,mm,nn,geps,xval,
                    xmin, xmax, xold1,xold2,xlow,xupp,
                    mma_a,mma_c,cost,g,fmax,dc, dg)
            xold2 = xold1
            xold1 = xval
            xval = xmma
            x[:] = xmma

            if self.ft==0:	xPhys[:]=np.asarray(H*x[np.newaxis].T/Hs)[:,0]
            elif self.ft==1:
                xTilde[:] = np.asarray(H*x[np.newaxis].T/Hs)[:,0]
                xPhys[:] = 1-np.exp(-Hbeta*xTilde)+xTilde*np.exp(-Hbeta)
            change=np.abs(xmma-xold1).max()

            if self.ft==1 and Hbeta<512 and loopbeta >=50:# or change<=0.01):
                Hbeta = 2*Hbeta
                loopbeta = 0
                change = 1
                print('Parameter beta increased to %d.\n'%Hbeta)

            if loop>1:
                del fig, ax
            fig,ax = plt.subplots()
            im = ax.imshow(xPhys.reshape((self.nelx,self.nely)).T, cmap='gray_r',\
            interpolation='none',norm=colors.Normalize(vmin=0,vmax=1))
            fig.show()
            fig.canvas.draw()

            if loop%1==0:
                plt.savefig(folder_path+'TOdesign/design%d.png'%(loop))
                plt.close('all')
                np.savetxt(folder_path+'TOdesign/design%d.txt'%(loop),xPhys)

            print("it.: {0} , obj.: {1:.3f} Vol.: {2:.3f}, ch.: {3:.3f}".format(\
                        loop,cost,volume,change))

            gc.collect()

        end_time=time.time()-start_time
        print('total time is: ', end_time)
        plt.show()

    def mmaInit(self, m, n, volfrac):
        move = 0.5 # move limit
        geps = 1e-9  # 1e-7

        xmin = zeros([n,]) # 0.001*ones([3,])
        xmax= ones([n,])
        # xval = volfrac*ones([n,])
        xval = ones([n,])*self.x_init

        # vol/volfrac < 1 where RHS is fmax
        fmax = 1.*ones([m,])

        mma_a = 0.*ones([m,])
        mma_c = 1000.*ones([m,])

        return geps,xval,move, xmin,xmax,fmax,mma_a,mma_c


    def __call__(self):
        self.optimize()

# %%
to2d = TO2D_CMInverter(Lx=120,Ly=60,nelx=120,nely=60,filter=0,rmin=4.2,volfrac=0.3,x_init=0.3)
to2d.optimize()
# Out:
# 2D TO for CM Inverter
# Number of nodes: 120 x 60
# Volume fraction: 0.3, rmin: 4.2
# Filter method: Density based
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9842e-01,               total_loss=-4.9842e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9832e-01,               total_loss=-4.9832e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9853e-01,               total_loss=-4.9853e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9849e-01,               total_loss=-4.9849e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.0707e+02,               total_loss=-1.0707e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.0841e+02,               total_loss=-1.0841e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1667e+02,               total_loss=-1.1667e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.0620e+02,               total_loss=-1.0620e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 1 , obj.: 0.010 Vol.: 0.300, ch.: 0.344
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9992e-01,               total_loss=-4.9992e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9986e-01,               total_loss=-4.9986e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9983e-01,               total_loss=-4.9983e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9991e-01,               total_loss=-4.9991e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.1248e+02,               total_loss=-4.1248e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.3626e+02,               total_loss=-4.3626e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.3227e+02,               total_loss=-4.3227e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.3026e+02,               total_loss=-4.3026e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 2 , obj.: 0.015 Vol.: 0.210, ch.: 0.152
# *CB_ES* Loss didn't change much from last 20 epochs
# *CB_ES* Percent change in loss value: 0.0
# Callback_EarlyStopping signal received at epoch= 6
# Terminating training
#
# Train ends after 6 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.0822e+02,               total_loss=-4.0822e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.3630e+02,               total_loss=-4.3630e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.1992e+02,               total_loss=-4.1992e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.1788e+02,               total_loss=-4.1788e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 3 , obj.: 0.013 Vol.: 0.216, ch.: 0.100
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9989e-01,               total_loss=-4.9989e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9982e-01,               total_loss=-4.9982e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9991e-01,               total_loss=-4.9991e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9989e-01,               total_loss=-4.9989e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.4280e+02,               total_loss=-4.4280e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.3546e+02,               total_loss=-4.3546e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.0433e+02,               total_loss=-4.0433e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.2454e+02,               total_loss=-4.2454e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 4 , obj.: 0.010 Vol.: 0.224, ch.: 0.085
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9990e-01,               total_loss=-4.9990e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9987e-01,               total_loss=-4.9987e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9987e-01,               total_loss=-4.9987e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9991e-01,               total_loss=-4.9991e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.1557e+02,               total_loss=-4.1557e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.2092e+02,               total_loss=-4.2092e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.0744e+02,               total_loss=-4.0744e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.2163e+02,               total_loss=-4.2163e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 5 , obj.: 0.007 Vol.: 0.223, ch.: 0.113
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9990e-01,               total_loss=-4.9990e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9987e-01,               total_loss=-4.9987e-01
# *CB_ES* Loss didn't change much from last 20 epochs
# *CB_ES* Percent change in loss value: 0.0
# Callback_EarlyStopping signal received at epoch= 103
# Terminating training
#
# Train ends after 103 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-3.7272e+02,               total_loss=-3.7272e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-3.8276e+02,               total_loss=-3.8276e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.0766e+02,               total_loss=-4.0766e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.0448e+02,               total_loss=-4.0448e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 6 , obj.: 0.005 Vol.: 0.224, ch.: 0.162
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9989e-01,               total_loss=-4.9989e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9988e-01,               total_loss=-4.9988e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9990e-01,               total_loss=-4.9990e-01
# *CB_ES* Loss didn't change much from last 20 epochs
# *CB_ES* Percent change in loss value: 0.0
# Callback_EarlyStopping signal received at epoch= 151
# Terminating training
#
# Train ends after 151 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.5920e+02,               total_loss=-2.5920e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.5806e+02,               total_loss=-2.5806e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.6245e+02,               total_loss=-2.6245e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.5302e+02,               total_loss=-2.5302e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 7 , obj.: -0.002 Vol.: 0.228, ch.: 0.156
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9987e-01,               total_loss=-4.9987e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9991e-01,               total_loss=-4.9991e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9990e-01,               total_loss=-4.9990e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9991e-01,               total_loss=-4.9991e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.3398e+02,               total_loss=-2.3398e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.2523e+02,               total_loss=-2.2523e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.4775e+02,               total_loss=-2.4775e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.2722e+02,               total_loss=-2.2722e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 8 , obj.: -0.002 Vol.: 0.234, ch.: 0.177
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9971e-01,               total_loss=-4.9971e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9962e-01,               total_loss=-4.9962e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9906e-01,               total_loss=-4.9906e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9969e-01,               total_loss=-4.9969e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.2353e+02,               total_loss=-2.2353e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.2407e+02,               total_loss=-2.2407e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.1009e+02,               total_loss=-2.1009e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.2026e+02,               total_loss=-2.2026e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 9 , obj.: -0.009 Vol.: 0.242, ch.: 0.269
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9933e-01,               total_loss=-4.9933e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9931e-01,               total_loss=-4.9931e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9929e-01,               total_loss=-4.9929e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9847e-01,               total_loss=-4.9847e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.9977e+02,               total_loss=-1.9977e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.0357e+02,               total_loss=-2.0357e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.1214e+02,               total_loss=-2.1214e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.0715e+02,               total_loss=-2.0715e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 10 , obj.: -0.016 Vol.: 0.260, ch.: 0.342
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9928e-01,               total_loss=-4.9928e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9912e-01,               total_loss=-4.9912e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9913e-01,               total_loss=-4.9913e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9888e-01,               total_loss=-4.9888e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.9178e+02,               total_loss=-1.9178e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.9547e+02,               total_loss=-1.9547e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.1276e+02,               total_loss=-2.1276e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.9102e+02,               total_loss=-1.9102e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 11 , obj.: -0.020 Vol.: 0.262, ch.: 0.379
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9792e-01,               total_loss=-4.9792e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9899e-01,               total_loss=-4.9899e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9859e-01,               total_loss=-4.9859e-01
# *CB_ES* Loss didn't change much from last 20 epochs
# *CB_ES* Percent change in loss value: 0.0
# Callback_EarlyStopping signal received at epoch= 163
# Terminating training
#
# Train ends after 163 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.9824e+02,               total_loss=-1.9824e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.9625e+02,               total_loss=-1.9625e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-2.0148e+02,               total_loss=-2.0148e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.8897e+02,               total_loss=-1.8897e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 12 , obj.: -0.035 Vol.: 0.266, ch.: 0.359
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9930e-01,               total_loss=-4.9930e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9920e-01,               total_loss=-4.9920e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9825e-01,               total_loss=-4.9825e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9814e-01,               total_loss=-4.9814e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.9196e+02,               total_loss=-1.9196e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.7938e+02,               total_loss=-1.7938e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.9812e+02,               total_loss=-1.9812e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.7167e+02,               total_loss=-1.7167e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 13 , obj.: -0.023 Vol.: 0.277, ch.: 0.371
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9908e-01,               total_loss=-4.9908e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9881e-01,               total_loss=-4.9881e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9892e-01,               total_loss=-4.9892e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9889e-01,               total_loss=-4.9889e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.7324e+02,               total_loss=-1.7324e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5818e+02,               total_loss=-1.5818e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.8050e+02,               total_loss=-1.8050e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.7563e+02,               total_loss=-1.7563e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 14 , obj.: -0.035 Vol.: 0.283, ch.: 0.404
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9882e-01,               total_loss=-4.9882e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9875e-01,               total_loss=-4.9875e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9883e-01,               total_loss=-4.9883e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9895e-01,               total_loss=-4.9895e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.7695e+02,               total_loss=-1.7695e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.7714e+02,               total_loss=-1.7714e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.8074e+02,               total_loss=-1.8074e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.8196e+02,               total_loss=-1.8196e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 15 , obj.: -0.028 Vol.: 0.285, ch.: 0.275
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9886e-01,               total_loss=-4.9886e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9869e-01,               total_loss=-4.9869e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9770e-01,               total_loss=-4.9770e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9879e-01,               total_loss=-4.9879e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5772e+02,               total_loss=-1.5772e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6876e+02,               total_loss=-1.6876e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6119e+02,               total_loss=-1.6119e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.7258e+02,               total_loss=-1.7258e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 16 , obj.: -0.033 Vol.: 0.288, ch.: 0.373
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9886e-01,               total_loss=-4.9886e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9865e-01,               total_loss=-4.9865e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9897e-01,               total_loss=-4.9897e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9876e-01,               total_loss=-4.9876e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5892e+02,               total_loss=-1.5892e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6333e+02,               total_loss=-1.6333e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6684e+02,               total_loss=-1.6684e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.7507e+02,               total_loss=-1.7507e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 17 , obj.: -0.033 Vol.: 0.288, ch.: 0.354
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9882e-01,               total_loss=-4.9882e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9833e-01,               total_loss=-4.9833e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9866e-01,               total_loss=-4.9866e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9873e-01,               total_loss=-4.9873e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5228e+02,               total_loss=-1.5228e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6211e+02,               total_loss=-1.6211e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5698e+02,               total_loss=-1.5698e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.0867e+02,               total_loss=-1.0867e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 18 , obj.: -0.045 Vol.: 0.290, ch.: 0.348
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9879e-01,               total_loss=-4.9879e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9817e-01,               total_loss=-4.9817e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9863e-01,               total_loss=-4.9863e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9807e-01,               total_loss=-4.9807e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6127e+02,               total_loss=-1.6127e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6807e+02,               total_loss=-1.6807e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5586e+02,               total_loss=-1.5586e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5415e+02,               total_loss=-1.5415e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 19 , obj.: -0.048 Vol.: 0.290, ch.: 0.321
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9862e-01,               total_loss=-4.9862e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9849e-01,               total_loss=-4.9849e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9853e-01,               total_loss=-4.9853e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9840e-01,               total_loss=-4.9840e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5518e+02,               total_loss=-1.5518e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6068e+02,               total_loss=-1.6068e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6558e+02,               total_loss=-1.6558e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6531e+02,               total_loss=-1.6531e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 20 , obj.: -0.043 Vol.: 0.291, ch.: 0.285
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9475e-01,               total_loss=-4.9475e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9876e-01,               total_loss=-4.9876e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9727e-01,               total_loss=-4.9727e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9870e-01,               total_loss=-4.9870e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5724e+02,               total_loss=-1.5724e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6248e+02,               total_loss=-1.6248e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2972e+02,               total_loss=-1.2972e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4518e+02,               total_loss=-1.4518e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 0s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 21 , obj.: -0.048 Vol.: 0.291, ch.: 0.391
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9579e-01,               total_loss=-4.9579e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9830e-01,               total_loss=-4.9830e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9844e-01,               total_loss=-4.9844e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9816e-01,               total_loss=-4.9816e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4923e+02,               total_loss=-1.4923e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3777e+02,               total_loss=-1.3777e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6145e+02,               total_loss=-1.6145e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5369e+02,               total_loss=-1.5369e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 22 , obj.: -0.045 Vol.: 0.292, ch.: 0.381
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9833e-01,               total_loss=-4.9833e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9830e-01,               total_loss=-4.9830e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9808e-01,               total_loss=-4.9808e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9814e-01,               total_loss=-4.9814e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5130e+02,               total_loss=-1.5130e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.6064e+02,               total_loss=-1.6064e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5692e+02,               total_loss=-1.5692e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5707e+02,               total_loss=-1.5707e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 23 , obj.: -0.059 Vol.: 0.292, ch.: 0.303
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9815e-01,               total_loss=-4.9815e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9837e-01,               total_loss=-4.9837e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9810e-01,               total_loss=-4.9810e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9617e-01,               total_loss=-4.9617e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3919e+02,               total_loss=-1.3919e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5833e+02,               total_loss=-1.5833e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4621e+02,               total_loss=-1.4621e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5124e+02,               total_loss=-1.5124e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 24 , obj.: -0.061 Vol.: 0.292, ch.: 0.362
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9742e-01,               total_loss=-4.9742e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9824e-01,               total_loss=-4.9824e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9819e-01,               total_loss=-4.9819e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9828e-01,               total_loss=-4.9828e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4356e+02,               total_loss=-1.4356e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4658e+02,               total_loss=-1.4658e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3552e+02,               total_loss=-1.3552e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4239e+02,               total_loss=-1.4239e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 25 , obj.: -0.045 Vol.: 0.292, ch.: 0.422
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9784e-01,               total_loss=-4.9784e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9822e-01,               total_loss=-4.9822e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9800e-01,               total_loss=-4.9800e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9826e-01,               total_loss=-4.9826e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4614e+02,               total_loss=-1.4614e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4105e+02,               total_loss=-1.4105e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4481e+02,               total_loss=-1.4481e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4567e+02,               total_loss=-1.4567e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 26 , obj.: -0.075 Vol.: 0.292, ch.: 0.349
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9780e-01,               total_loss=-4.9780e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9815e-01,               total_loss=-4.9815e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9821e-01,               total_loss=-4.9821e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9805e-01,               total_loss=-4.9805e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=9.2779e+01,               total_loss=9.2779e+01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3724e+02,               total_loss=-1.3724e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5137e+02,               total_loss=-1.5137e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4041e+02,               total_loss=-1.4041e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 27 , obj.: -0.073 Vol.: 0.292, ch.: 0.349
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9786e-01,               total_loss=-4.9786e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9807e-01,               total_loss=-4.9807e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9815e-01,               total_loss=-4.9815e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9814e-01,               total_loss=-4.9814e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4473e+02,               total_loss=-1.4473e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4591e+02,               total_loss=-1.4591e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4549e+02,               total_loss=-1.4549e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1199e+02,               total_loss=-1.1199e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 28 , obj.: -0.069 Vol.: 0.292, ch.: 0.358
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9791e-01,               total_loss=-4.9791e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9813e-01,               total_loss=-4.9813e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9808e-01,               total_loss=-4.9808e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9809e-01,               total_loss=-4.9809e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5286e+02,               total_loss=-1.5286e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5266e+02,               total_loss=-1.5266e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4054e+02,               total_loss=-1.4054e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3760e+02,               total_loss=-1.3760e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 29 , obj.: -0.081 Vol.: 0.292, ch.: 0.352
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9804e-01,               total_loss=-4.9804e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9618e-01,               total_loss=-4.9618e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9816e-01,               total_loss=-4.9816e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9768e-01,               total_loss=-4.9768e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4126e+02,               total_loss=-1.4126e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4483e+02,               total_loss=-1.4483e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4168e+02,               total_loss=-1.4168e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5287e+02,               total_loss=-1.5287e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 30 , obj.: -0.089 Vol.: 0.292, ch.: 0.374
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9789e-01,               total_loss=-4.9789e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9770e-01,               total_loss=-4.9770e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9764e-01,               total_loss=-4.9764e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9803e-01,               total_loss=-4.9803e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3067e+02,               total_loss=-1.3067e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4867e+02,               total_loss=-1.4867e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4934e+02,               total_loss=-1.4934e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4221e+02,               total_loss=-1.4221e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 31 , obj.: -0.067 Vol.: 0.292, ch.: 0.309
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9735e-01,               total_loss=-4.9735e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9763e-01,               total_loss=-4.9763e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9761e-01,               total_loss=-4.9761e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9780e-01,               total_loss=-4.9780e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4756e+02,               total_loss=-1.4756e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4592e+02,               total_loss=-1.4592e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4438e+02,               total_loss=-1.4438e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.5232e+02,               total_loss=-1.5232e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 32 , obj.: -0.079 Vol.: 0.292, ch.: 0.315
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9758e-01,               total_loss=-4.9758e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9769e-01,               total_loss=-4.9769e-01
# *CB_ES* Loss didn't change much from last 20 epochs
# *CB_ES* Percent change in loss value: 0.0
# Callback_EarlyStopping signal received at epoch= 139
# Terminating training
#
# Train ends after 139 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2918e+02,               total_loss=-1.2918e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2915e+02,               total_loss=-1.2915e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3969e+02,               total_loss=-1.3969e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4077e+02,               total_loss=-1.4077e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 4ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 33 , obj.: -0.084 Vol.: 0.293, ch.: 0.406
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9583e-01,               total_loss=-4.9583e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9764e-01,               total_loss=-4.9764e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9775e-01,               total_loss=-4.9775e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9805e-01,               total_loss=-4.9805e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3674e+02,               total_loss=-1.3674e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2368e+02,               total_loss=-1.2368e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4162e+02,               total_loss=-1.4162e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4379e+02,               total_loss=-1.4379e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 34 , obj.: -0.089 Vol.: 0.293, ch.: 0.289
# *CB_ES* Loss didn't change much from last 20 epochs
# *CB_ES* Percent change in loss value: 0.0
# Callback_EarlyStopping signal received at epoch= 4
# Terminating training
#
# Train ends after 4 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4040e+02,               total_loss=-1.4040e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.4162e+02,               total_loss=-1.4162e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3253e+02,               total_loss=-1.3253e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3679e+02,               total_loss=-1.3679e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 35 , obj.: -0.089 Vol.: 0.293, ch.: 0.225
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9744e-01,               total_loss=-4.9744e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9712e-01,               total_loss=-4.9712e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9782e-01,               total_loss=-4.9782e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9738e-01,               total_loss=-4.9738e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3384e+02,               total_loss=-1.3384e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3983e+02,               total_loss=-1.3983e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2999e+02,               total_loss=-1.2999e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3739e+02,               total_loss=-1.3739e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 36 , obj.: -0.094 Vol.: 0.293, ch.: 0.371
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9739e-01,               total_loss=-4.9739e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9743e-01,               total_loss=-4.9743e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9736e-01,               total_loss=-4.9736e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9749e-01,               total_loss=-4.9749e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3027e+02,               total_loss=-1.3027e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3287e+02,               total_loss=-1.3287e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3232e+02,               total_loss=-1.3232e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3066e+02,               total_loss=-1.3066e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 37 , obj.: -0.098 Vol.: 0.294, ch.: 0.294
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9755e-01,               total_loss=-4.9755e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9746e-01,               total_loss=-4.9746e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9675e-01,               total_loss=-4.9675e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9711e-01,               total_loss=-4.9711e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3227e+02,               total_loss=-1.3227e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2732e+02,               total_loss=-1.2732e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3696e+02,               total_loss=-1.3696e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3323e+02,               total_loss=-1.3323e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 38 , obj.: -0.105 Vol.: 0.293, ch.: 0.241
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9434e-01,               total_loss=-4.9434e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9726e-01,               total_loss=-4.9726e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9707e-01,               total_loss=-4.9707e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9698e-01,               total_loss=-4.9698e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3333e+02,               total_loss=-1.3333e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3025e+02,               total_loss=-1.3025e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3365e+02,               total_loss=-1.3365e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2894e+02,               total_loss=-1.2894e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 39 , obj.: -0.097 Vol.: 0.293, ch.: 0.343
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9735e-01,               total_loss=-4.9735e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9646e-01,               total_loss=-4.9646e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9657e-01,               total_loss=-4.9657e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9734e-01,               total_loss=-4.9734e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2976e+02,               total_loss=-1.2976e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2703e+02,               total_loss=-1.2703e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1932e+02,               total_loss=-1.1932e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2771e+02,               total_loss=-1.2771e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 40 , obj.: -0.111 Vol.: 0.293, ch.: 0.382
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9718e-01,               total_loss=-4.9718e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9691e-01,               total_loss=-4.9691e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9585e-01,               total_loss=-4.9585e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9677e-01,               total_loss=-4.9677e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2853e+02,               total_loss=-1.2853e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2343e+02,               total_loss=-1.2343e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2699e+02,               total_loss=-1.2699e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3208e+02,               total_loss=-1.3208e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 41 , obj.: -0.122 Vol.: 0.293, ch.: 0.421
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9682e-01,               total_loss=-4.9682e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9715e-01,               total_loss=-4.9715e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9725e-01,               total_loss=-4.9725e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9704e-01,               total_loss=-4.9704e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1974e+02,               total_loss=-1.1974e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3411e+02,               total_loss=-1.3411e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3248e+02,               total_loss=-1.3248e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2325e+02,               total_loss=-1.2325e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 42 , obj.: -0.132 Vol.: 0.292, ch.: 0.365
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9662e-01,               total_loss=-4.9662e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9704e-01,               total_loss=-4.9704e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9698e-01,               total_loss=-4.9698e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9674e-01,               total_loss=-4.9674e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3098e+02,               total_loss=-1.3098e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2576e+02,               total_loss=-1.2576e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3118e+02,               total_loss=-1.3118e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.3013e+02,               total_loss=-1.3013e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 43 , obj.: -0.117 Vol.: 0.293, ch.: 0.342
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9725e-01,               total_loss=-4.9725e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9700e-01,               total_loss=-4.9700e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9669e-01,               total_loss=-4.9669e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9627e-01,               total_loss=-4.9627e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2576e+02,               total_loss=-1.2576e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2937e+02,               total_loss=-1.2937e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2622e+02,               total_loss=-1.2622e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2287e+02,               total_loss=-1.2287e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 44 , obj.: -0.106 Vol.: 0.293, ch.: 0.343
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9675e-01,               total_loss=-4.9675e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9655e-01,               total_loss=-4.9655e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9634e-01,               total_loss=-4.9634e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9591e-01,               total_loss=-4.9591e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2082e+02,               total_loss=-1.2082e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2806e+02,               total_loss=-1.2806e+02
# Epoch 150:
# lr: 1.00e-03
# ...
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2866e+02,               total_loss=-1.2866e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2616e+02,               total_loss=-1.2616e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2173e+02,               total_loss=-1.2173e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 49 , obj.: -0.160 Vol.: 0.296, ch.: 0.336
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9655e-01,               total_loss=-4.9655e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9668e-01,               total_loss=-4.9668e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9667e-01,               total_loss=-4.9667e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9653e-01,               total_loss=-4.9653e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2541e+02,               total_loss=-1.2541e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2744e+02,               total_loss=-1.2744e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2590e+02,               total_loss=-1.2590e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2760e+02,               total_loss=-1.2760e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 50 , obj.: -0.168 Vol.: 0.296, ch.: 0.254
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9610e-01,               total_loss=-4.9610e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9640e-01,               total_loss=-4.9640e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9583e-01,               total_loss=-4.9583e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9584e-01,               total_loss=-4.9584e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2447e+02,               total_loss=-1.2447e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1282e+02,               total_loss=-1.1282e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2496e+02,               total_loss=-1.2496e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1405e+02,               total_loss=-1.1405e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 51 , obj.: -0.149 Vol.: 0.296, ch.: 0.288
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9635e-01,               total_loss=-4.9635e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9627e-01,               total_loss=-4.9627e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9626e-01,               total_loss=-4.9626e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9577e-01,               total_loss=-4.9577e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2266e+02,               total_loss=-1.2266e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2301e+02,               total_loss=-1.2301e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2863e+02,               total_loss=-1.2863e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2188e+02,               total_loss=-1.2188e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 52 , obj.: -0.157 Vol.: 0.297, ch.: 0.448
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9619e-01,               total_loss=-4.9619e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9623e-01,               total_loss=-4.9623e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9591e-01,               total_loss=-4.9591e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9590e-01,               total_loss=-4.9590e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2080e+02,               total_loss=-1.2080e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2422e+02,               total_loss=-1.2422e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2525e+02,               total_loss=-1.2525e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2465e+02,               total_loss=-1.2465e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 53 , obj.: -0.163 Vol.: 0.297, ch.: 0.389
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9201e-01,               total_loss=-4.9201e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9636e-01,               total_loss=-4.9636e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9626e-01,               total_loss=-4.9626e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9630e-01,               total_loss=-4.9630e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2562e+02,               total_loss=-1.2562e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2365e+02,               total_loss=-1.2365e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2469e+02,               total_loss=-1.2469e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1956e+02,               total_loss=-1.1956e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 54 , obj.: -0.154 Vol.: 0.297, ch.: 0.340
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9526e-01,               total_loss=-4.9526e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9588e-01,               total_loss=-4.9588e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9610e-01,               total_loss=-4.9610e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9638e-01,               total_loss=-4.9638e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1989e+02,               total_loss=-1.1989e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1985e+02,               total_loss=-1.1985e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=1.2072e+01,               total_loss=1.2072e+01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1971e+02,               total_loss=-1.1971e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 55 , obj.: -0.178 Vol.: 0.296, ch.: 0.376
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9609e-01,               total_loss=-4.9609e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9574e-01,               total_loss=-4.9574e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9579e-01,               total_loss=-4.9579e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9627e-01,               total_loss=-4.9627e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2364e+02,               total_loss=-1.2364e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2412e+02,               total_loss=-1.2412e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2201e+02,               total_loss=-1.2201e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2337e+02,               total_loss=-1.2337e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 3ms/step
# it.: 56 , obj.: -0.160 Vol.: 0.296, ch.: 0.500
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9638e-01,               total_loss=-4.9638e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9635e-01,               total_loss=-4.9635e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9467e-01,               total_loss=-4.9467e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9644e-01,               total_loss=-4.9644e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2112e+02,               total_loss=-1.2112e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2470e+02,               total_loss=-1.2470e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1924e+02,               total_loss=-1.1924e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2160e+02,               total_loss=-1.2160e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 57 , obj.: -0.169 Vol.: 0.296, ch.: 0.462
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9616e-01,               total_loss=-4.9616e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9599e-01,               total_loss=-4.9599e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9566e-01,               total_loss=-4.9566e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9618e-01,               total_loss=-4.9618e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2379e+02,               total_loss=-1.2379e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2503e+02,               total_loss=-1.2503e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2708e+02,               total_loss=-1.2708e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2344e+02,               total_loss=-1.2344e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 58 , obj.: -0.168 Vol.: 0.297, ch.: 0.310
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9639e-01,               total_loss=-4.9639e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9495e-01,               total_loss=-4.9495e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9603e-01,               total_loss=-4.9603e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9566e-01,               total_loss=-4.9566e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1641e+02,               total_loss=-1.1641e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2392e+02,               total_loss=-1.2392e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2345e+02,               total_loss=-1.2345e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2342e+02,               total_loss=-1.2342e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 59 , obj.: -0.161 Vol.: 0.297, ch.: 0.337
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9514e-01,               total_loss=-4.9514e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.8575e-01,               total_loss=-4.8575e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9554e-01,               total_loss=-4.9554e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9582e-01,               total_loss=-4.9582e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1214e+02,               total_loss=-1.1214e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2244e+02,               total_loss=-1.2244e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1901e+02,               total_loss=-1.1901e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-8.2437e+01,               total_loss=-8.2437e+01
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 4ms/step
# it.: 60 , obj.: -0.176 Vol.: 0.297, ch.: 0.264
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9588e-01,               total_loss=-4.9588e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9570e-01,               total_loss=-4.9570e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9608e-01,               total_loss=-4.9608e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9604e-01,               total_loss=-4.9604e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2384e+02,               total_loss=-1.2384e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1659e+02,               total_loss=-1.1659e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2176e+02,               total_loss=-1.2176e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2100e+02,               total_loss=-1.2100e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 3ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 61 , obj.: -0.173 Vol.: 0.298, ch.: 0.355
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9563e-01,               total_loss=-4.9563e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9585e-01,               total_loss=-4.9585e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9582e-01,               total_loss=-4.9582e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9611e-01,               total_loss=-4.9611e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-9.0365e+01,               total_loss=-9.0365e+01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2028e+02,               total_loss=-1.2028e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.1624e+02,               total_loss=-1.1624e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2136e+02,               total_loss=-1.2136e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 62 , obj.: -0.172 Vol.: 0.298, ch.: 0.331
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9585e-01,               total_loss=-4.9585e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9574e-01,               total_loss=-4.9574e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9589e-01,               total_loss=-4.9589e-01
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9598e-01,               total_loss=-4.9598e-01
# Train ends after 200 epochs
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2444e+02,               total_loss=-1.2444e+02
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2495e+02,               total_loss=-1.2495e+02
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2211e+02,               total_loss=-1.2211e+02
# Epoch 200:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-1.2490e+02,               total_loss=-1.2490e+02
# Train ends after 200 epochs
# 231/231 [==============================] - 1s 2ms/step
# 231/231 [==============================] - 1s 2ms/step
# it.: 63 , obj.: -0.198 Vol.: 0.298, ch.: 0.391
# Epoch 50:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9566e-01,               total_loss=-4.9566e-01
# Epoch 100:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9561e-01,               total_loss=-4.9561e-01
# Epoch 150:
# lr: 1.00e-03
# Data=0.0000e+00,               PDE=-4.9591e-01,               total_loss=-4.9591e-01
