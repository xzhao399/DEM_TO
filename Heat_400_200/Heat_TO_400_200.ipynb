# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install necessary packages
# !pip install tf_fourier_features
# !pip install geomdl
# Out:
# Collecting tf_fourier_features
#   Downloading tf_fourier_features-0.0.2.1-py2.py3-none-any.whl (6.2 kB)
# Requirement already satisfied: tensorflow>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from tf_fourier_features) (2.15.0)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from tf_fourier_features) (1.25.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.2.0->tf_fourier_features) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.2.0->tf_fourier_features) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.2.0->tf_fourier_features) (3.2.2)
# Installing collected packages: tf_fourier_features
# Successfully installed tf_fourier_features-0.0.2.1
# Collecting geomdl
#   Downloading geomdl-5.3.1-py2.py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: geomdl
# Successfully installed geomdl-5.3.1

# %%
# # compile the mma for the current python version
# !cd {folder_path}MMA && sh compile.sh

# %%
# import standard packages
from __future__ import division
from numpy import *
import numpy as np
from scipy.sparse import coo_matrix
from matplotlib import colors
import matplotlib.pyplot as plt
import tensorflow as tf
import sys
import time
import os
import gc
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
# path of current folder
folder_path = '/content/drive/MyDrive/DEM_TO/Heat/'
# add the path to python's search list
sys.path.append(folder_path)
sys.path.append(folder_path+'UtilityFunctions')

# %%
# import custimized modules
import utils as ut
import surrogate_model_primal as sm_pr
from mma import mmasub

# %%
# use gpu for tensorflow
if tf.config.list_physical_devices('GPU'):
  physical_devices = tf.config.list_physical_devices('GPU')
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
  print('Using GPU')
else:
  print('Using CPU')
# Out:
# Using GPU

# %%
ut.makepath(folder_path+'TOdesign')
ut.makepath(folder_path+'surrogate_result')
ut.makepath(folder_path+'model_pr')
# Out:
# '/content/drive/MyDrive/DEM_TO/Heat/surrogate_result/'

# %%
class TO2D_heat():
    def __init__(self,Lx=100,Ly=50,nelx=100,nely=50,volfrac=0.5,rmin=3,maxiter=1000,filter=0,x_init=0.5):
        self.Lx = Lx
        self.Ly = Ly
        self.nelx = nelx
        self.nely = nely
        self.volfrac = volfrac
        self.rmin = rmin
        self.maxiter = maxiter
        self.ft = filter
        self.x_init = x_init* np.ones(self.nely*self.nelx,dtype=float)
        print("2D TO for heat sink")
        print("Number of nodes: " + str(self.nelx) + " x " + str(self.nely))
        print("Volume fraction: " + str(self.volfrac) + ", rmin: " + str(self.rmin))
        print("Filter method: " + ["Density based","Density based + Heaviside filter"][self.ft])

    def optimize(self):
        x = self.x_init.copy()
        nn = len(x)
        mm = 1
        [geps,xval,move,xmin,xmax,fmax,mma_a,mma_c] = self.mmaInit(mm, nn, self.volfrac)
        xlow = xmin
        xupp = xmax
        xold1 = xval
        xold2 = xval

        Hbeta = 1
        if self.ft==0:
            xPhys=x.copy()
        elif self.ft==1:
            xTilde=x.copy()
            xPhys=1-np.exp(-Hbeta*xTilde)+xTilde*np.exp(-Hbeta)

        H,Hs = ut.DensityFilter_init(self.rmin,self.nelx,self.nely)

        k0 = 1
        kmin = 1e-3
        p = 3

        Nsample = 40000

        Xint, Wint, _, _, eleidx = ut.getquadpts(L=self.Lx,H=self.Ly,Nelmufem=self.nelx,Nelmvfem=self.nely,numElemU=self.nelx,numElemV=self.nely,numGauss=2,bdcode=1)
        input_dof,evenidx,oddidx = ut.generatedofcoord(nelx=self.nelx,nely=self.nely,L=self.Lx,H=self.Ly)
        Wint = np.squeeze(Wint)

        mesh = {'nelx':self.nelx,'nely':self.nely,'L':self.Lx/100,'H':self.Ly/100,\
        'eleidx':eleidx,'Xint':Xint/100,'input_dof':input_dof/100,'evenidx':evenidx,'oddidx':oddidx,'Nsample':Nsample}

        material = {'volfrac':self.volfrac, 'k': k0, 'kmin': kmin, 'p':p, 's':0.001*(100)**2/117.65}

        lr = 1e-3
        Nepoch = 10
        batch_size = 2000
        neuron = 86
        rff_dev = 1.32
        N_Layers = 4
        act_func = 'swish'
        N_input_rho = self.nelx*self.nely
        N_input_coord = 2
        trainParams={'lr':lr,'Nepoch':Nepoch,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}

        self.SModel_pr = sm_pr.SurrogateModel_primal()
        self.SModel_pr.updatemesh(mesh)
        self.SModel_pr.updatematerial(material)
        self.SModel_pr.updatetrainParams(trainParams)

        X_DBC = np.zeros((5000,2))
        X_DBC[:,0] = 0.
        X_DBC[:,1] = np.linspace(0,self.Ly/10,5000)

        # Set loop counter and gradient vectors
        loop=0
        loopbeta=0
        iter=0
        change=1
        dv = np.ones(self.nely*self.nelx)
        dc = np.ones(self.nely*self.nelx)
        start_time=time.time()
        while change>-1 and loop<=self.maxiter:
            loop=loop+1
            loopbeta=loopbeta+1
            iter += 1
            rho_int = xPhys[eleidx]

            data = {'rho_quad':rho_int,'DBC':X_DBC/100}
            if loop==1:
              trainParams={'lr':lr,'Nepoch':1000,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}
            else:
              trainParams={'lr':lr,'Nepoch':Nepoch,'Nbatch':batch_size,'Nneuron':neuron,'rff_dev':rff_dev,'Nlayers':N_Layers,'activation':act_func,'N_input_rho':N_input_rho,'N_input_coord':N_input_coord}
            self.SModel_pr.updatetrainParams(trainParams)

            self.SModel_pr.updatetrainset(data)
            if loop==1:
                self.SModel_pr.initialize_model()

            self.SModel_pr.trainmodel(verbose=True)
            print('Train ends after %d epochs'%self.SModel_pr.Endepoch)

            self.SModel_pr.Model.save(folder_path+'model_pr/model_pr.h5')

            t = self.SModel_pr.Model.predict(input_dof/100)
            t = t*117.65

            ut.plotdesign(folder_path+'surrogate_result/','current_design',xPhys,nelx=self.nelx,nely=self.nely)
            ut.plotresult_contour(folder_path+'surrogate_result/','solution_T',input_dof,t,L=self.Lx,H=self.Ly)

            volume = np.sum(xPhys)/(self.nelx*self.nely)
            dv = np.ones(self.nely*self.nelx)/self.nelx/self.nely

            T_dx,T_dy = self.SModel_pr.nabla_T(ut.preprocess(Xint[:,0]/100),ut.preprocess(Xint[:,1]/100))
            F_GQ = (T_dx*(117.65/self.Lx))**2+(T_dy*(117.65/self.Lx))**2

            #calculate cost
            FW_c = np.squeeze(F_GQ)*Wint*(kmin+(k0-kmin)*rho_int**3)
            cost = np.sum(FW_c)

            #calculate sensitivity
            FW_dc = np.squeeze(F_GQ)*Wint
            FW_dc = np.reshape(FW_dc,(-1,4))
            FW_dc = np.sum(FW_dc,axis=1)
            dc[:][eleidx[0::4]] = FW_dc
            dc = -1/2*(3*(xPhys**(3-1))*(k0-kmin))*dc

            if iter==1:
                cost0 = cost
            if self.ft==0:
                dc[:] = np.asarray(H*(dc[np.newaxis].T/Hs))[:,0]
                dv[:] = np.asarray(H*(dv[np.newaxis].T/Hs))[:,0]
            elif self.ft==1:
                dx = Hbeta*np.exp(-Hbeta*xTilde)+np.exp(-Hbeta)
                dc[:] = np.asarray(H*((dc*dx)[np.newaxis].T/Hs))[:,0]
                dv[:] = np.asarray(H*((dv*dx)[np.newaxis].T/Hs))[:,0]

            xold2 = xold1.copy()
            xold1 = x.copy()
            g = volume/self.volfrac
            dg = dv/self.volfrac

            xmin = maximum(zeros([nn,]), xval-move)
            xmax = minimum(ones([nn,]), xval+move)
            [iyfree,xmma,xlow,xupp,alfa,beta,mma_b,mma_y,mma_z,ulam,mma_p,mma_q,p0,q0,uu,gradf,dsrch,hessf] = \
                mmasub(iter,mm,nn,geps,xval,
                    xmin, xmax, xold1,xold2,xlow,xupp,
                    mma_a,mma_c,cost/cost0,g,fmax,dc/cost0, dg)
            xold2 = xold1
            xold1 = xval
            xval = xmma
            x[:] = xmma


            if self.ft==0:	xPhys[:]=np.asarray(H*x[np.newaxis].T/Hs)[:,0]
            elif self.ft==1:
                xTilde[:] = np.asarray(H*x[np.newaxis].T/Hs)[:,0]
                xPhys[:] = 1-np.exp(-Hbeta*xTilde)+xTilde*np.exp(-Hbeta)
            change=np.abs(xmma-xold1).max()

            if self.ft==1 and Hbeta<512 and loopbeta >=50:# or change<=0.01):
                Hbeta = 2*Hbeta
                loopbeta = 0
                change = 1
                print('Parameter beta increased to %d.\n'%Hbeta)

            if loop>1:
                del fig, ax

            fig,ax = plt.subplots()
            im = ax.imshow(xPhys.reshape((self.nelx,self.nely)).T, cmap='gray_r',\
            interpolation='none',norm=colors.Normalize(vmin=0,vmax=1))
            fig.show()
            fig.canvas.draw()

            if loop%1==0:
                plt.savefig(folder_path+'TOdesign/design%d.png'%(loop))
                plt.close('all')
                np.savetxt(folder_path+'TOdesign/design%d.txt'%(loop),xPhys)

            print("it.: {0} , obj.: {1:.3f} Vol.: {2:.3f}, ch.: {3:.3f}".format(\
                        loop,cost,volume,change))

            gc.collect()

        end_time=time.time()-start_time
        print('total time is: ', end_time)
        plt.show()

    def mmaInit(self, m, n, volfrac):
        move = 0.5 # move limit
        geps = 1e-9  # 1e-7

        xmin = zeros([n,]) # 0.001*ones([3,])
        xmax= ones([n,])
        # xval = volfrac*ones([n,])
        xval = ones([n,])*self.x_init

        # vol/volfrac < 1 where RHS is fmax
        fmax = 1.*ones([m,])

        mma_a = 0.*ones([m,])
        mma_c = 1000.*ones([m,])

        return geps,xval,move, xmin,xmax,fmax,mma_a,mma_c


    def __call__(self):
        self.optimize()

# %%
to2d= TO2D_heat(Lx=100,Ly=50,nelx=400,nely=200,filter=0,rmin=4.2,volfrac=0.5,x_init=0.5,maxiter=500)
to2d.optimize()
# Out:
# 2D TO for heat sink
# Number of nodes: 400 x 200
# Volume fraction: 0.5, rmin: 4.2
# Filter method: Density based
# Epoch 50:
# lr: 1.00e-03
# Data=4.9334e-04,               PDE=-8.6055e-03,               total_loss=-8.1122e-03
# Epoch 100:
# lr: 1.00e-03
# Data=6.6819e-04,               PDE=-1.3137e-02,               total_loss=-1.2469e-02
# Epoch 150:
# lr: 1.00e-03
# Data=7.1454e-04,               PDE=-1.2651e-02,               total_loss=-1.1937e-02
# Epoch 200:
# lr: 1.00e-03
# Data=6.0737e-04,               PDE=-1.3119e-02,               total_loss=-1.2511e-02
# Epoch 250:
# lr: 1.00e-03
# Data=6.3579e-04,               PDE=-1.3501e-02,               total_loss=-1.2865e-02
# Epoch 300:
# lr: 1.00e-03
# Data=6.6724e-04,               PDE=-1.3236e-02,               total_loss=-1.2568e-02
# Epoch 350:
# lr: 1.00e-03
# Data=6.7710e-04,               PDE=-1.3400e-02,               total_loss=-1.2723e-02
# Epoch 400:
# lr: 1.00e-03
# Data=6.4123e-04,               PDE=-1.3805e-02,               total_loss=-1.3164e-02
# Epoch 450:
# lr: 1.00e-03
# Data=6.3919e-04,               PDE=-1.3240e-02,               total_loss=-1.2601e-02
# Epoch 500:
# lr: 1.00e-03
# Data=6.3291e-04,               PDE=-1.3988e-02,               total_loss=-1.3355e-02
# Epoch 550:
# lr: 1.00e-03
# Data=6.8152e-04,               PDE=-1.3807e-02,               total_loss=-1.3125e-02
# Epoch 600:
# lr: 1.00e-03
# Data=6.8537e-04,               PDE=-1.3818e-02,               total_loss=-1.3133e-02
# Epoch 650:
# lr: 1.00e-03
# Data=6.7147e-04,               PDE=-1.3599e-02,               total_loss=-1.2927e-02
# Epoch 700:
# lr: 1.00e-03
# Data=7.0633e-04,               PDE=-1.4084e-02,               total_loss=-1.3378e-02
# Epoch 750:
# lr: 1.00e-03
# Data=6.3427e-04,               PDE=-1.4122e-02,               total_loss=-1.3488e-02
# Epoch 800:
# lr: 1.00e-03
# Data=6.2942e-04,               PDE=-1.3901e-02,               total_loss=-1.3271e-02
# Epoch 850:
# lr: 1.00e-03
# Data=6.0060e-04,               PDE=-1.4236e-02,               total_loss=-1.3635e-02
# Epoch 900:
# lr: 1.00e-03
# Data=6.5641e-04,               PDE=-1.4211e-02,               total_loss=-1.3555e-02
# Epoch 950:
# lr: 1.00e-03
# Data=6.5643e-04,               PDE=-1.4133e-02,               total_loss=-1.3476e-02
# Epoch 1000:
# lr: 1.00e-03
# Data=7.1884e-04,               PDE=-1.4395e-02,               total_loss=-1.3676e-02
# Train ends after 1000 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 1 , obj.: 391.005 Vol.: 0.500, ch.: 0.414
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 2 , obj.: 186.195 Vol.: 0.463, ch.: 0.161
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 3 , obj.: 130.995 Vol.: 0.485, ch.: 0.087
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 4 , obj.: 116.080 Vol.: 0.495, ch.: 0.059
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 5 , obj.: 116.424 Vol.: 0.497, ch.: 0.048
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 6 , obj.: 100.990 Vol.: 0.498, ch.: 0.041
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 7 , obj.: 93.298 Vol.: 0.499, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 8 , obj.: 94.065 Vol.: 0.499, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 9 , obj.: 93.155 Vol.: 0.499, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 10 , obj.: 89.954 Vol.: 0.499, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 11 , obj.: 100.506 Vol.: 0.499, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 12 , obj.: 84.020 Vol.: 0.499, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 13 , obj.: 84.896 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 14 , obj.: 81.683 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 15 , obj.: 90.029 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 16 , obj.: 73.854 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 17 , obj.: 82.718 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 18 , obj.: 88.269 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 19 , obj.: 92.886 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 20 , obj.: 77.033 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 21 , obj.: 84.538 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 22 , obj.: 80.525 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 23 , obj.: 84.179 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 24 , obj.: 75.657 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 25 , obj.: 73.702 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 26 , obj.: 86.245 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 27 , obj.: 74.244 Vol.: 0.500, ch.: 0.044
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 28 , obj.: 77.778 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 29 , obj.: 89.807 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 30 , obj.: 81.316 Vol.: 0.500, ch.: 0.040
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 31 , obj.: 78.467 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 32 , obj.: 81.286 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 33 , obj.: 79.915 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 34 , obj.: 79.579 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 35 , obj.: 78.253 Vol.: 0.500, ch.: 0.051
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 36 , obj.: 75.207 Vol.: 0.500, ch.: 0.041
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 37 , obj.: 72.861 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 38 , obj.: 72.958 Vol.: 0.500, ch.: 0.043
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 39 , obj.: 69.610 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 40 , obj.: 81.175 Vol.: 0.500, ch.: 0.041
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 41 , obj.: 75.306 Vol.: 0.500, ch.: 0.053
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 42 , obj.: 78.390 Vol.: 0.500, ch.: 0.044
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 43 , obj.: 83.558 Vol.: 0.500, ch.: 0.050
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 44 , obj.: 74.025 Vol.: 0.500, ch.: 0.046
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 45 , obj.: 71.803 Vol.: 0.500, ch.: 0.050
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 46 , obj.: 75.402 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 47 , obj.: 66.390 Vol.: 0.500, ch.: 0.047
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 48 , obj.: 74.844 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 49 , obj.: 67.827 Vol.: 0.500, ch.: 0.067
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 50 , obj.: 74.309 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 51 , obj.: 66.371 Vol.: 0.500, ch.: 0.045
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 52 , obj.: 75.149 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 53 , obj.: 78.816 Vol.: 0.500, ch.: 0.048
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 54 , obj.: 73.660 Vol.: 0.500, ch.: 0.048
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 55 , obj.: 73.714 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 56 , obj.: 74.626 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 57 , obj.: 70.455 Vol.: 0.500, ch.: 0.047
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 58 , obj.: 68.594 Vol.: 0.500, ch.: 0.040
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 59 , obj.: 66.712 Vol.: 0.500, ch.: 0.040
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 60 , obj.: 61.066 Vol.: 0.500, ch.: 0.047
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 61 , obj.: 65.706 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 62 , obj.: 69.689 Vol.: 0.500, ch.: 0.044
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 63 , obj.: 64.798 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 64 , obj.: 63.254 Vol.: 0.500, ch.: 0.051
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 65 , obj.: 60.083 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 66 , obj.: 67.761 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 67 , obj.: 73.815 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 68 , obj.: 76.205 Vol.: 0.500, ch.: 0.044
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 69 , obj.: 62.395 Vol.: 0.500, ch.: 0.051
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 70 , obj.: 62.585 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 71 , obj.: 68.708 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 72 , obj.: 67.427 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 73 , obj.: 68.603 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 74 , obj.: 66.557 Vol.: 0.500, ch.: 0.044
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 75 , obj.: 67.965 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 76 , obj.: 67.785 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 77 , obj.: 64.737 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 78 , obj.: 69.191 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 79 , obj.: 60.428 Vol.: 0.500, ch.: 0.047
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 80 , obj.: 60.289 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 81 , obj.: 73.963 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 82 , obj.: 65.379 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 83 , obj.: 60.152 Vol.: 0.500, ch.: 0.043
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 84 , obj.: 58.570 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 85 , obj.: 63.964 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 86 , obj.: 56.752 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 87 , obj.: 60.861 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 88 , obj.: 66.157 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 89 , obj.: 59.549 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 90 , obj.: 60.832 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 91 , obj.: 64.340 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 92 , obj.: 64.540 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 93 , obj.: 65.214 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 94 , obj.: 63.683 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 95 , obj.: 64.209 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 96 , obj.: 59.430 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 97 , obj.: 63.723 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 98 , obj.: 61.110 Vol.: 0.500, ch.: 0.042
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 99 , obj.: 73.274 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 100 , obj.: 65.692 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 101 , obj.: 65.320 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 102 , obj.: 63.656 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 103 , obj.: 64.146 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 104 , obj.: 69.220 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 105 , obj.: 67.266 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 106 , obj.: 59.665 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 107 , obj.: 58.578 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 108 , obj.: 63.143 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 109 , obj.: 62.893 Vol.: 0.500, ch.: 0.047
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 110 , obj.: 60.673 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 111 , obj.: 60.002 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 112 , obj.: 61.476 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 113 , obj.: 59.926 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 114 , obj.: 65.094 Vol.: 0.500, ch.: 0.041
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 115 , obj.: 63.273 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 116 , obj.: 59.755 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 117 , obj.: 66.406 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 118 , obj.: 63.442 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 119 , obj.: 55.388 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 120 , obj.: 61.740 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 121 , obj.: 65.902 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 122 , obj.: 55.311 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 123 , obj.: 60.621 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 124 , obj.: 67.467 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 125 , obj.: 62.387 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 126 , obj.: 57.659 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 127 , obj.: 62.546 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 128 , obj.: 61.184 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 129 , obj.: 59.364 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 130 , obj.: 61.207 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 131 , obj.: 56.471 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 132 , obj.: 62.994 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 133 , obj.: 60.393 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 134 , obj.: 54.588 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 135 , obj.: 66.526 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 136 , obj.: 57.931 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 137 , obj.: 57.892 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 138 , obj.: 54.829 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 139 , obj.: 62.499 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 140 , obj.: 62.494 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 141 , obj.: 65.349 Vol.: 0.500, ch.: 0.047
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 142 , obj.: 58.757 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 143 , obj.: 64.914 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 144 , obj.: 63.376 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 145 , obj.: 70.153 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 146 , obj.: 60.552 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 147 , obj.: 61.101 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 148 , obj.: 60.571 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 149 , obj.: 57.280 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 150 , obj.: 61.831 Vol.: 0.500, ch.: 0.043
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 151 , obj.: 62.564 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 152 , obj.: 62.970 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 153 , obj.: 56.062 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 154 , obj.: 64.593 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 155 , obj.: 64.211 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 156 , obj.: 61.056 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 157 , obj.: 66.371 Vol.: 0.500, ch.: 0.041
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 158 , obj.: 63.594 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 159 , obj.: 62.438 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 160 , obj.: 62.384 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 161 , obj.: 55.150 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 162 , obj.: 62.493 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 163 , obj.: 69.784 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 164 , obj.: 63.556 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 165 , obj.: 63.202 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 166 , obj.: 57.502 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 167 , obj.: 60.167 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 168 , obj.: 62.285 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 169 , obj.: 61.349 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 170 , obj.: 58.091 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 171 , obj.: 70.458 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 172 , obj.: 61.516 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 173 , obj.: 62.762 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 174 , obj.: 61.565 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 175 , obj.: 64.751 Vol.: 0.500, ch.: 0.044
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 176 , obj.: 57.761 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 177 , obj.: 59.735 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 178 , obj.: 58.544 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 179 , obj.: 65.288 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 180 , obj.: 63.864 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 181 , obj.: 52.962 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 182 , obj.: 57.309 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 183 , obj.: 57.553 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 184 , obj.: 65.936 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 185 , obj.: 53.732 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 186 , obj.: 67.909 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 187 , obj.: 59.745 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 188 , obj.: 62.611 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 189 , obj.: 66.677 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 190 , obj.: 56.154 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 191 , obj.: 60.146 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 192 , obj.: 59.444 Vol.: 0.500, ch.: 0.040
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 193 , obj.: 61.358 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 194 , obj.: 63.347 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 195 , obj.: 60.523 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 196 , obj.: 61.937 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 197 , obj.: 63.535 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 198 , obj.: 57.185 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 199 , obj.: 65.368 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 200 , obj.: 61.217 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 201 , obj.: 60.254 Vol.: 0.500, ch.: 0.041
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 202 , obj.: 60.607 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 203 , obj.: 60.813 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 204 , obj.: 57.844 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 205 , obj.: 55.150 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 206 , obj.: 63.415 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 207 , obj.: 64.165 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 208 , obj.: 56.744 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 209 , obj.: 66.400 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 210 , obj.: 58.902 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 211 , obj.: 67.867 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 212 , obj.: 69.269 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 213 , obj.: 75.612 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 214 , obj.: 63.562 Vol.: 0.500, ch.: 0.043
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 215 , obj.: 65.951 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 216 , obj.: 60.620 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 217 , obj.: 57.326 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 218 , obj.: 59.785 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 219 , obj.: 59.951 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 220 , obj.: 59.779 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 221 , obj.: 60.350 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 222 , obj.: 63.346 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 223 , obj.: 57.820 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 224 , obj.: 62.306 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 225 , obj.: 59.108 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 226 , obj.: 57.716 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 227 , obj.: 59.043 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 228 , obj.: 56.139 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 229 , obj.: 56.441 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 230 , obj.: 60.005 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 231 , obj.: 59.204 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 232 , obj.: 66.217 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 233 , obj.: 62.199 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 234 , obj.: 57.860 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 235 , obj.: 61.776 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 236 , obj.: 65.266 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 237 , obj.: 65.551 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 238 , obj.: 67.245 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 239 , obj.: 61.182 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 240 , obj.: 62.696 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 241 , obj.: 57.136 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 242 , obj.: 61.587 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 243 , obj.: 62.523 Vol.: 0.500, ch.: 0.037
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 244 , obj.: 62.583 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 245 , obj.: 56.502 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 246 , obj.: 55.693 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 247 , obj.: 57.489 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 248 , obj.: 60.307 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 249 , obj.: 68.004 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 250 , obj.: 53.179 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 251 , obj.: 57.076 Vol.: 0.500, ch.: 0.048
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 252 , obj.: 59.979 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 253 , obj.: 56.711 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 254 , obj.: 55.929 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 255 , obj.: 57.182 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 256 , obj.: 61.379 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 257 , obj.: 55.020 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 258 , obj.: 61.503 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 259 , obj.: 62.834 Vol.: 0.500, ch.: 0.041
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 260 , obj.: 61.856 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 261 , obj.: 61.654 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 262 , obj.: 59.462 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 263 , obj.: 60.441 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 264 , obj.: 63.195 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 265 , obj.: 59.640 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 266 , obj.: 65.162 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 267 , obj.: 65.334 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 268 , obj.: 72.708 Vol.: 0.500, ch.: 0.047
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 269 , obj.: 55.897 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 270 , obj.: 60.768 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 271 , obj.: 58.732 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 272 , obj.: 63.780 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 273 , obj.: 65.414 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 274 , obj.: 55.478 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 275 , obj.: 59.117 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 276 , obj.: 58.834 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 277 , obj.: 59.581 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 278 , obj.: 57.156 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 279 , obj.: 59.487 Vol.: 0.500, ch.: 0.044
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 280 , obj.: 54.865 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 281 , obj.: 55.908 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 282 , obj.: 62.632 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 283 , obj.: 55.283 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 284 , obj.: 68.615 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 285 , obj.: 60.202 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 286 , obj.: 61.405 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 287 , obj.: 60.350 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 288 , obj.: 60.929 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 289 , obj.: 60.045 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 290 , obj.: 58.452 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 291 , obj.: 61.968 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 292 , obj.: 64.469 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 293 , obj.: 56.786 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 294 , obj.: 64.440 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 295 , obj.: 63.420 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 296 , obj.: 67.037 Vol.: 0.500, ch.: 0.058
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 297 , obj.: 63.544 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 298 , obj.: 60.192 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 299 , obj.: 54.736 Vol.: 0.500, ch.: 0.014
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 300 , obj.: 59.658 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 301 , obj.: 60.003 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 302 , obj.: 59.455 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 303 , obj.: 60.134 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 304 , obj.: 62.259 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 305 , obj.: 59.621 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 306 , obj.: 57.197 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 307 , obj.: 58.658 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 308 , obj.: 61.346 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 309 , obj.: 57.300 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 310 , obj.: 57.018 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 311 , obj.: 60.342 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 312 , obj.: 61.536 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 313 , obj.: 61.007 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 314 , obj.: 60.444 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 315 , obj.: 60.644 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 316 , obj.: 58.074 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 317 , obj.: 59.835 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 318 , obj.: 63.243 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 319 , obj.: 66.304 Vol.: 0.500, ch.: 0.045
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 320 , obj.: 55.751 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 321 , obj.: 61.989 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 322 , obj.: 62.190 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 323 , obj.: 61.787 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 324 , obj.: 57.313 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 2ms/step
# it.: 325 , obj.: 59.806 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 326 , obj.: 60.512 Vol.: 0.500, ch.: 0.039
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 327 , obj.: 58.692 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 328 , obj.: 61.872 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 329 , obj.: 59.449 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 330 , obj.: 59.635 Vol.: 0.500, ch.: 0.014
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 331 , obj.: 56.009 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 332 , obj.: 56.270 Vol.: 0.500, ch.: 0.041
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 333 , obj.: 61.708 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 334 , obj.: 63.493 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 335 , obj.: 60.085 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 336 , obj.: 54.628 Vol.: 0.500, ch.: 0.035
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 337 , obj.: 58.417 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 338 , obj.: 68.091 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 339 , obj.: 61.925 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 340 , obj.: 55.361 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 341 , obj.: 60.732 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 342 , obj.: 64.762 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 343 , obj.: 66.122 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 344 , obj.: 56.793 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 345 , obj.: 59.061 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 346 , obj.: 61.643 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 347 , obj.: 59.653 Vol.: 0.500, ch.: 0.025
# ...
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 381 , obj.: 60.305 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 382 , obj.: 55.962 Vol.: 0.500, ch.: 0.013
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 383 , obj.: 62.918 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 384 , obj.: 59.696 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 385 , obj.: 59.249 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 386 , obj.: 60.632 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 387 , obj.: 55.408 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 388 , obj.: 57.472 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 389 , obj.: 61.145 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 390 , obj.: 58.931 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 391 , obj.: 58.375 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 392 , obj.: 62.306 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 393 , obj.: 59.649 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 394 , obj.: 58.369 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 395 , obj.: 60.338 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 396 , obj.: 54.679 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 397 , obj.: 59.300 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 398 , obj.: 59.236 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 399 , obj.: 63.024 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 400 , obj.: 56.048 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 401 , obj.: 57.103 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 402 , obj.: 66.546 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 403 , obj.: 57.823 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 404 , obj.: 59.919 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 405 , obj.: 63.283 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 406 , obj.: 60.889 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 407 , obj.: 60.208 Vol.: 0.500, ch.: 0.048
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 408 , obj.: 60.049 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 409 , obj.: 55.671 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 410 , obj.: 58.944 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 411 , obj.: 59.883 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 412 , obj.: 56.660 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 413 , obj.: 59.095 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 414 , obj.: 58.921 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 415 , obj.: 56.242 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 416 , obj.: 60.803 Vol.: 0.500, ch.: 0.033
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 417 , obj.: 61.599 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 418 , obj.: 57.811 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 419 , obj.: 59.757 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 420 , obj.: 65.549 Vol.: 0.500, ch.: 0.018
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 421 , obj.: 57.197 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 422 , obj.: 62.738 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 423 , obj.: 60.176 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 424 , obj.: 59.106 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 425 , obj.: 55.860 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 426 , obj.: 64.871 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 427 , obj.: 67.128 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 428 , obj.: 58.304 Vol.: 0.500, ch.: 0.044
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 429 , obj.: 57.294 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 430 , obj.: 63.244 Vol.: 0.500, ch.: 0.034
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 431 , obj.: 57.416 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 432 , obj.: 60.094 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 433 , obj.: 56.109 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 434 , obj.: 64.027 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 435 , obj.: 57.624 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 436 , obj.: 58.374 Vol.: 0.500, ch.: 0.014
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 437 , obj.: 65.369 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 438 , obj.: 59.483 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 439 , obj.: 57.086 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 440 , obj.: 59.186 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 441 , obj.: 57.542 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 442 , obj.: 64.772 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 443 , obj.: 61.709 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 444 , obj.: 60.227 Vol.: 0.500, ch.: 0.014
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 445 , obj.: 59.233 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 446 , obj.: 61.896 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 447 , obj.: 59.585 Vol.: 0.500, ch.: 0.031
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 448 , obj.: 67.024 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 449 , obj.: 59.009 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 450 , obj.: 57.206 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 451 , obj.: 59.547 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 452 , obj.: 57.091 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 453 , obj.: 58.462 Vol.: 0.500, ch.: 0.023
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 454 , obj.: 59.259 Vol.: 0.500, ch.: 0.036
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 455 , obj.: 58.910 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 456 , obj.: 60.979 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 457 , obj.: 59.561 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 458 , obj.: 67.265 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 459 , obj.: 60.556 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 460 , obj.: 63.420 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 461 , obj.: 55.940 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 462 , obj.: 55.872 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 463 , obj.: 66.469 Vol.: 0.500, ch.: 0.032
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 464 , obj.: 63.317 Vol.: 0.500, ch.: 0.029
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 465 , obj.: 65.328 Vol.: 0.500, ch.: 0.025
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 466 , obj.: 55.485 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 467 , obj.: 58.303 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 468 , obj.: 64.013 Vol.: 0.500, ch.: 0.021
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 469 , obj.: 59.554 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 470 , obj.: 57.421 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 471 , obj.: 67.580 Vol.: 0.500, ch.: 0.026
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 472 , obj.: 65.191 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 473 , obj.: 54.925 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 474 , obj.: 60.109 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 475 , obj.: 59.012 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 476 , obj.: 61.387 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 477 , obj.: 62.327 Vol.: 0.500, ch.: 0.022
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 478 , obj.: 56.976 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 479 , obj.: 64.373 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 480 , obj.: 66.044 Vol.: 0.500, ch.: 0.028
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 481 , obj.: 61.650 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 482 , obj.: 60.598 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 3s 1ms/step
# it.: 483 , obj.: 61.553 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 484 , obj.: 58.066 Vol.: 0.500, ch.: 0.019
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 485 , obj.: 63.441 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 486 , obj.: 60.505 Vol.: 0.500, ch.: 0.030
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 487 , obj.: 71.526 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 488 , obj.: 56.132 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 489 , obj.: 60.405 Vol.: 0.500, ch.: 0.014
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 490 , obj.: 62.696 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 491 , obj.: 60.903 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 492 , obj.: 57.540 Vol.: 0.500, ch.: 0.024
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 493 , obj.: 56.508 Vol.: 0.500, ch.: 0.020
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 494 , obj.: 57.415 Vol.: 0.500, ch.: 0.015
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 495 , obj.: 57.363 Vol.: 0.500, ch.: 0.017
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 496 , obj.: 61.667 Vol.: 0.500, ch.: 0.038
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 497 , obj.: 61.852 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 498 , obj.: 60.051 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 499 , obj.: 65.800 Vol.: 0.500, ch.: 0.016
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 500 , obj.: 68.645 Vol.: 0.500, ch.: 0.027
# Train ends after 10 epochs
# 2519/2519 [==============================] - 4s 1ms/step
# it.: 501 , obj.: 60.478 Vol.: 0.500, ch.: 0.025
# total time is:  7171.431464910507
